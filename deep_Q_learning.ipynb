# %%
# %pip install ucimlrepo pandas numpy scikit-learn openpyxl requests
# Install PyTorch if needed
# %pip install torch torchvision torchaudio --quiet
# Out:
# Requirement already satisfied: ucimlrepo in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (0.0.7)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.7.2)
# Requirement already satisfied: openpyxl in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (3.1.5)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.32.5)
# Requirement already satisfied: certifi>=2020.12.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ucimlrepo) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests) (2.6.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import requests
from io import BytesIO

# ML imports
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from collections import defaultdict
import matplotlib.pyplot as plt

# %% [markdown]
# ### Download and import UC-Irvine online retail dataset

# %%
# Download the Online Retail dataset from UCI repository using requests
# (requests handles SSL better than urllib)
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx"

print("Downloading Online Retail dataset from UCI repository...")
try:
    # Use requests library which handles SSL certificates better
    response = requests.get(url, verify=False)  # verify=False bypasses SSL verification
    response.raise_for_status()
    
    # Read the Excel file from the downloaded content
    df = pd.read_excel(BytesIO(response.content), engine='openpyxl')
    print("✓ Dataset loaded successfully!")
    
    # Display dataset information
    print(f"\nDataset shape: {df.shape}")
    print(f"Rows: {df.shape[0]:,}, Columns: {df.shape[1]}")
    print(f"\nColumns: {list(df.columns)}")
    print(f"\nFirst few rows:")
    display(df.head())
    print(f"\nData types:")
    # print(df.dtypes)
    # print(f"\nBasic statistics:")
    # print(df.describe())
    
except Exception as e:
    print(f"Error: {e}")
    print("\nPlease check your internet connection or try again later.")
# Out:
# Downloading Online Retail dataset from UCI repository...
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'archive.ics.uci.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ✓ Dataset loaded successfully!
#
# Dataset shape: (541909, 8)
# Rows: 541,909, Columns: 8
#
# Columns: ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country']
#
# First few rows:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# Data types:

# %% [markdown]
# ### Preprocess into a pricing learning table

# %%
def preprocess(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    # Parse datetime
    df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"], errors="coerce")
    df = df.dropna(subset=["InvoiceDate", "StockCode", "Quantity", "UnitPrice"])

    # Remove cancellations/returns and non-positive values
    # UCI notes InvoiceNo starting with 'C' indicates cancellation. :contentReference[oaicite:4]{index=4}
    df["InvoiceNo"] = df["InvoiceNo"].astype(str)
    df = df[~df["InvoiceNo"].str.startswith("C")]
    df = df[(df["Quantity"] > 0) & (df["UnitPrice"] > 0)]

    # Keep only products with enough observations (helps learning stability)
    df = df[df["StockCode"].astype(str).str.len() > 0]

    # Aggregate to daily product level
    df["date"] = df["InvoiceDate"].dt.date
    g = df.groupby(["StockCode", "date"], as_index=False).agg(
        qty=("Quantity", "sum"),
        price=("UnitPrice", "mean"),
        n_txn=("InvoiceNo", "nunique"),
    )

    # Add time features
    g["date"] = pd.to_datetime(g["date"])
    g["dow"] = g["date"].dt.dayofweek
    g["month"] = g["date"].dt.month

    # Lag features (per product)
    g = g.sort_values(["StockCode", "date"])
    g["qty_lag1"] = g.groupby("StockCode")["qty"].shift(1)
    g["qty_lag7"] = g.groupby("StockCode")["qty"].shift(7)

    # Fill missing lags with 0 (cold start)
    g[["qty_lag1", "qty_lag7"]] = g[["qty_lag1", "qty_lag7"]].fillna(0)

    return g

data = preprocess(df)
display(data.tail(20))
# Out:
#            StockCode       date  qty  price  n_txn  dow  month  qty_lag1  \
# 276128  gift_0001_20 2011-04-19    1  16.67      1    1      4       2.0
# 276129  gift_0001_20 2011-06-20    1  16.67      1    0      6       1.0
# 276130  gift_0001_20 2011-06-24    1  16.67      1    4      6       1.0
# 276131  gift_0001_20 2011-08-04    1  16.67      1    3      8       1.0
# 276132  gift_0001_20 2011-10-31    1  16.67      1    0     10       1.0
# 276133  gift_0001_30 2011-01-05    1  25.53      1    2      1       0.0
# 276134  gift_0001_30 2011-02-17    1  25.00      1    3      2       1.0
# 276135  gift_0001_30 2011-02-18    1  25.00      1    4      2       1.0
# 276136  gift_0001_30 2011-05-31    1  25.00      1    1      5       1.0
# 276137  gift_0001_30 2011-08-10    1  25.00      1    2      8       1.0
# 276138  gift_0001_30 2011-08-30    1  25.00      1    1      8       1.0
# 276139  gift_0001_30 2011-09-02    1  25.00      1    4      9       1.0
# 276140  gift_0001_40 2010-12-20    1  34.04      1    0     12       0.0
# 276141  gift_0001_40 2011-04-04    1  33.33      1    0      4       1.0
# 276142  gift_0001_40 2011-07-27    1  33.33      1    2      7       1.0
# 276143  gift_0001_50 2010-12-23    1  42.55      1    3     12       0.0
# 276144  gift_0001_50 2011-05-06    1  41.67      1    4      5       1.0
# 276145  gift_0001_50 2011-06-24    1  41.67      1    4      6       1.0
# 276146  gift_0001_50 2011-06-30    1  41.67      1    3      6       1.0
# 276147             m 2010-12-21    1   2.55      1    1     12       0.0
#
#         qty_lag7
# 276128       0.0
# 276129       0.0
# 276130       0.0
# 276131       1.0
# 276132       1.0
# 276133       0.0
# 276134       0.0
# 276135       0.0
# 276136       0.0
# 276137       0.0
# 276138       0.0
# 276139       0.0
# 276140       0.0
# 276141       0.0
# 276142       0.0
# 276143       0.0
# 276144       0.0
# 276145       0.0
# 276146       0.0
# 276147       0.0

# %%
data['StockCode'].nunique()
# Out:
# 3922

# %% [markdown]
# ### Fit a simple demand model from offline data:
#
# $$ log(1+qty) = \beta_0 + \beta_1 log(price) + context $$

# %%
def fit_demand_model(data: pd.DataFrame):
    d = data.copy()
    d["log_qty"] = np.log1p(d["qty"])
    d["log_price"] = np.log(d["price"])

    # identify which features are numerical and which are categorical
    features_num = ["log_price", "qty_lag1", "qty_lag7", "n_txn"]
    features_cat = ["dow", "month"]

    X = d[features_num + features_cat]
    y = d["log_qty"]

    # For numerical features, we pass them through as-is
    # For categorical features, we apply one-hot encoding
    pre = ColumnTransformer(
        transformers=[
            ("num", "passthrough", features_num),
            ("cat", OneHotEncoder(handle_unknown="ignore"), features_cat),
        ]
    )

    # Build the full pipeline with preprocessing and (Ridge)-regression model
    model = Pipeline(steps=[
        ("pre", pre),
        # ("reg", Ridge(alpha=1.0)),
        ("reg", LinearRegression()),
    ])

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)
    model.fit(X_train, y_train)

    r2 = model.score(X_test, y_test)
    print(f"Demand model R^2 on log_qty: {r2:.3f}")
    return model

demand_model = fit_demand_model(data)
# Out:
# Demand model R^2 on log_qty: 0.470

# %%
# Extract and display demand model coefficients
def extract_demand_coefficients(model, data):
    """
    Extract and interpret coefficients from the demand model.
    
    Args:
        model: Trained sklearn Pipeline with preprocessing and regression
        data: DataFrame used for training (to get feature names)
    
    Returns:
        DataFrame with coefficient names and values
    """
    # Get the regression model (last step in pipeline)
    reg_model = model.named_steps['reg']
    
    # Get feature names from the preprocessor
    preprocessor = model.named_steps['pre']
    
    # Get feature names after transformation
    feature_names = []
    
    # Numerical features (passthrough)
    num_features = ["log_price", "qty_lag1", "qty_lag7", "n_txn"]
    feature_names.extend(num_features)
    
    # Categorical features (one-hot encoded)
    cat_transformer = preprocessor.named_transformers_['cat']
    cat_feature_names = cat_transformer.get_feature_names_out(['dow', 'month'])
    feature_names.extend(cat_feature_names)
    
    # Get coefficients
    coefficients = reg_model.coef_
    intercept = reg_model.intercept_
    
    # Create DataFrame
    coef_df = pd.DataFrame({
        'Feature': ['Intercept'] + feature_names,
        'Coefficient': [intercept] + list(coefficients),
        'Abs_Coefficient': [abs(intercept)] + list(np.abs(coefficients))
    })
    
    # Sort by absolute value to see most important features
    coef_df_sorted = coef_df.sort_values('Abs_Coefficient', ascending=False)
    
    # Print results
    print("=" * 70)
    print("DEMAND MODEL COEFFICIENTS")
    print("=" * 70)
    print(f"\nModel: log(1 + qty) = β₀ + β₁·log(price) + β₂·qty_lag1 + ... + ε\n")
    
    print("Top 10 Most Important Features:")
    print("-" * 70)
    for idx, row in coef_df_sorted.head(10).iterrows():
        feature = row['Feature']
        coef = row['Coefficient']
        print(f"  {feature:25s}: {coef:8.4f}")
    
    print("\n" + "=" * 70)
    print("KEY INSIGHTS")
    print("=" * 70)
    
    # Price elasticity
    price_coef = coef_df[coef_df['Feature'] == 'log_price']['Coefficient'].values[0]
    print(f"\nPrice Elasticity: {price_coef:.4f}")
    if price_coef < 0:
        print(f"  → 1% increase in price → {abs(price_coef):.2f}% decrease in quantity")
        print(f"  → Demand is {'elastic' if abs(price_coef) > 1 else 'inelastic'}")
    else:
        print(f"  → WARNING: Positive price coefficient (unusual!)")
    
    # Lag features
    qty_lag1_coef = coef_df[coef_df['Feature'] == 'qty_lag1']['Coefficient'].values[0]
    qty_lag7_coef = coef_df[coef_df['Feature'] == 'qty_lag7']['Coefficient'].values[0]
    
    print(f"\nLag Effects:")
    print(f"  qty_lag1: {qty_lag1_coef:7.4f} → Yesterday's demand {'increases' if qty_lag1_coef > 0 else 'decreases'} today's")
    print(f"  qty_lag7: {qty_lag7_coef:7.4f} → Last week's demand {'increases' if qty_lag7_coef > 0 else 'decreases'} today's")
    
    # Day of week effects
    print(f"\nDay of Week Effects:")
    dow_features = coef_df[coef_df['Feature'].str.contains('dow_')]
    for _, row in dow_features.iterrows():
        day_num = row['Feature'].split('_')[-1]
        days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
        day_name = days[int(float(day_num))] if day_num.replace('.', '').isdigit() else day_num
        print(f"  {day_name}: {row['Coefficient']:7.4f}")
    
    print("\n" + "=" * 70)
    
    return coef_df_sorted


# Extract coefficients
coef_df = extract_demand_coefficients(demand_model, data)

# Display full coefficient table
print("\nFull Coefficient Table:")
display(coef_df)
# Out:
# ======================================================================
# DEMAND MODEL COEFFICIENTS
# ======================================================================
#
# Model: log(1 + qty) = β₀ + β₁·log(price) + β₂·qty_lag1 + ... + ε
#
# Top 10 Most Important Features:
# ----------------------------------------------------------------------
#   Intercept                :   1.6700
#   log_price                :  -0.4813
#   n_txn                    :   0.4451
#   dow_6                    :  -0.1696
#   month_12                 :  -0.1427
#   month_11                 :  -0.1329
#   month_8                  :   0.1166
#   dow_3                    :   0.1032
#   month_9                  :   0.1014
#   month_5                  :   0.0685
#
# ======================================================================
# KEY INSIGHTS
# ======================================================================
#
# Price Elasticity: -0.4813
#   → 1% increase in price → 0.48% decrease in quantity
#   → Demand is inelastic
#
# Lag Effects:
#   qty_lag1:  0.0001 → Yesterday's demand increases today's
#   qty_lag7:  0.0001 → Last week's demand increases today's
#
# Day of Week Effects:
#   Mon: -0.0374
#   Tue:  0.0027
#   Wed:  0.0429
#   Thu:  0.1032
#   Fri:  0.0581
#   Sun: -0.1696
#
# ======================================================================
#
# Full Coefficient Table:
#       Feature  Coefficient  Abs_Coefficient
# 0   Intercept     1.669960         1.669960
# 1   log_price    -0.481277         0.481277
# 4       n_txn     0.445101         0.445101
# 10      dow_6    -0.169596         0.169596
# 22   month_12    -0.142702         0.142702
# 21   month_11    -0.132905         0.132905
# 18    month_8     0.116640         0.116640
# 8       dow_3     0.103223         0.103223
# 19    month_9     0.101424         0.101424
# 15    month_5     0.068503         0.068503
# 11    month_1    -0.063708         0.063708
# 9       dow_4     0.058092         0.058092
# 17    month_7    -0.047670         0.047670
# 7       dow_2     0.042912         0.042912
# 5       dow_0    -0.037367         0.037367
# 13    month_3     0.031383         0.031383
# 12    month_2     0.030101         0.030101
# 16    month_6     0.016331         0.016331
# 20   month_10     0.013379         0.013379
# 14    month_4     0.009224         0.009224
# 6       dow_1     0.002735         0.002735
# 2    qty_lag1     0.000131         0.000131
# 3    qty_lag7     0.000118         0.000118

# %% [markdown]
# ### Build a simple Reinforcement Learning environment (model-based "offline RL")

# %%
# We’ll define actions as price multipliers around the observed price:
ACTION_MULTS = np.array([0.90, 0.95, 1.00, 1.05, 1.10, 1.15, 1.20, 1.25])

# %% [markdown]
# State will be a discretized tuple:
# - product id
# - day-of-week
# - lagged-qty bin
#
# Reward: Revenue = chosen price * simulated_qty
#
# Transition:
# - lag updates with simulated qty
# - day moves forward
#
# ### Environment + Q-Learning (tabular --> simple)
# - Classic Q-Learning learns a table:
# $ Q(s,a) $
# for every discrete state s and action a
# - State space must be finite, action space must be finite
# - Every pair (s,a) gets updated many times

# %% [markdown]
# ### Notes on standard and double-Q Learning
# Standard Q-learning learns action-value function $Q(s,a)$ with update:
# \begin{equation*}
# Q(s_t, a_t) \leftarrow Q(s_t, a_t) + \alpha \bigg( r_t + \gamma \, max_a Q(s_{t+1}, a) - Q(s_t, a_t) \bigg)
# \end{equation*}
# where $\alpha$ is a parameter that scale how much new information changes old estimate.
#
# Think of it like: $Q_{new} = (1-\alpha) Q_{old} + \alpha (new target)$. So:
# - Small $\alpha$ --> learn slowly
# - Large $\alpha$ --> learn fast but new Q-value is noisy and can be unstable
#
# $\gamma$ is the discount factor. It weights future rewards relative to immediate reward:
# \begin{equation*}
# Q(s,at) = E[ r_0 + \gamma r_1 + \gamma^2 r_2 + .... ]
# \end{equation*}
# So $\gamma=0$, we only care about immediate reward while $\gamma = 1$, long term consequences matter.
#
# Intuitively, we want RL agent to keep the mindset that "A slightly lower price today may keep demand (quantity) healthy and pay off later"
#
# In standard Q-Learning, we expect overestimating bias:
# \begin{equation*}
# E \bigg[ max_a Q(s,a) \bigg] \geq max_a E \bigg[ Q(s,a) \bigg]
# \end{equation*}
# Think of this as max() is convex. So when we take a max over noise then we tend to pick action that is overestimated (by noise).
#
# Bottom line: overestimation lead to aggressive policies (e.g., always increase price)
#
# ### Introduce Double-Q Learning:
# Double-Q learning keeps 2 separate Q-value estimate:
# \begin{align*}
# &Q^A(s,a) \\
# &Q^B(s,a)
# \end{align*}
# The trick:
# - use one table to select the best action for next state (argmax)
# - use other table to evaluate that selected action
# This decouples selection and evaluation --> reducing bias from max operator
#
# Update Rules: At each transition $(s_t, a_t, r_t, s_{t+1})$, flip a coin
# - Update $Q^A$ with probability 0.5:
#     - Best action selection using $Q^A$: $a^* = argmax_a \, Q^A(s_{t+1},a)$
#     - Evaluate that action using $Q^B$: $Y^A_t = r_t + \gamma \, Q^B(s_{t+1}, a^*)$
#     - Update $Q^A$:
# \begin{equation*}
# Q^A (s_t, a_t) \leftarrow Q^A (s_t, a_t) + \alpha \bigg( Y^A_t - Q^A(s_t, a_t) \bigg)
# \end{equation*}
#
# - Or Update $Q^B$ with probability 0.5: (using the same workflow & equations)
#
# This approach reduces overestimation because:
# - the action choosing task and evaluation task are done using 2 different Q-table
# - E.g., best action chosen from $Q^A$ while evaluation done in $Q^B$, or vice versa
# - Idea is: don't evaluate action choice using same-noise table: if noise in $Q^A$ and $Q^B$ is imperfectly correlated (they should differ because they're update differently on different steps), then the "lucky high" selection in $Q^A$ should not appear high in $Q^B$. Overall, leading to a less biased evaluation.
# - Analogy: use one model for choosing, another model for scoring -- this is a common bias/variance trick

# %%
def make_top_products(data: pd.DataFrame, top_k=200):
    """
    Get the top-k products by total quantity sold.
    """
    counts = data.groupby("StockCode")["qty"].sum().sort_values(ascending=False)
    top = counts.head(top_k).index.astype(str).tolist()
    return top

def build_episode_table(data: pd.DataFrame, top_products):
    """
    Build episode table for RL environment using only top products.
    """
    d = data[data["StockCode"].astype(str).isin(top_products)].copy()
    # Use each (product, date) row as a step; we’ll “simulate” what happens next
    d["StockCode"] = d["StockCode"].astype(str)
    d = d.sort_values(["StockCode", "date"])
    return d.reset_index(drop=True)

# Discretize lagged demand into bins
def qty_bin(q):
    """
    Discretize quantity into bins for state representation in Q-learning.
    Remember that qty is the predicted quantity sold. It is the target variable of demand model.
    We need to make the state space finite for tabular Q-learning.
    """
    # simple bins; tweak as desired:
    # We can think of this as the following:
    # q  < 1: no demand
    # 1  < q < 10: very low demand
    # 10 < q < 20: quite low demand
    # 20 < q < 30: still low demand but better
    # 30 < q < 40: low-medium demand
    # 40 < q < 50: medium demand
    # 50 < q < 100: high demand
    # 100< q < 200: very high demand
    # q > 200: extremely high demand
    if q < 1: return 0
    if q < 10: return 1
    if q < 20: return 2
    if q < 30: return 3
    if q < 40: return 4
    if q < 50: return 5
    if q < 100: return 6
    if q < 200: return 7
    return 8

# Using the demand model, predict quantity sold given a price and row features
def predict_qty(model, row_dict, price):
    """
    Predict quantity sold using the demand model.
    row_dict contains features like qty_lag1, qty_lag7, n_txn, dow, month
    Remark: dow and month are integers which will be one-hot encoded by the model
    """
    # Ensure price is positive and reasonable
    price = max(1e-6, float(price))
    
    # Check for invalid values in row_dict
    qty_lag1 = max(0.0, float(row_dict["qty_lag1"]))
    qty_lag7 = max(0.0, float(row_dict["qty_lag7"]))
    n_txn = max(1.0, float(row_dict["n_txn"]))
    
    x = {
        "log_price": np.log(price),
        "qty_lag1": qty_lag1,
        "qty_lag7": qty_lag7,
        "n_txn": n_txn,
        "dow": int(row_dict["dow"]),
        "month": int(row_dict["month"]),
    }
    X = pd.DataFrame([x])
    
    try:
        log_qty = float(model.predict(X)[0])
        # Clip log_qty to prevent extreme values
        log_qty = np.clip(log_qty, -10, 10)
        qty_hat = max(0.0, np.expm1(log_qty))
    except:
        qty_hat = 0.0
    
    return qty_hat


# -----------------------------
# 6) RL environment step
# -----------------------------
def env_step(model, row_dict, action_mult):
    """
    One-step transition:
      action_mult scales the base price
      reward is revenue = price * predicted_qty
      next_state uses qty_bin(predicted_qty)
      we update lags naively for the simulated next step
    """
    base_price = max(1e-6, float(row_dict["price"]))
    action_mult = max(0.1, min(2.0, float(action_mult)))  # Clamp action multiplier
    new_price = max(1e-6, base_price * action_mult)

    # Use demand-model to predict quantity sold at new_price
    qty_hat = predict_qty(model, row_dict, new_price)
    qty_hat = max(0.0, min(10000.0, qty_hat))  # Clamp quantity to reasonable range
    
    # compute reward using updated new_price
    # so that the method will learn how to pick price multiplier that maximizes expected revenue
    reward = new_price * qty_hat

    # Note: the predicted qty_hat is continuous, so we need to bin them to create discrete state value for quantity sold
    next_state = qty_bin(qty_hat)

    # Build the next row (next "state features") -- We need to know what carries forward
    # tomorrow's lag1 becomes today's predicted quantity
    # tomorrow's lag7 become today's lag1
    # Update lags for next step
    next_row = dict(row_dict)
    next_row["qty_lag7"] = max(0.0, float(row_dict["qty_lag1"]))
    next_row["qty_lag1"] = max(0.0, float(qty_hat))
    next_row["price"] = new_price
    # Keep other context fields stable
    next_row["n_txn"] = max(1.0, float(row_dict.get("n_txn", 1)))
    next_row["dow"] = int(row_dict["dow"])
    next_row["month"] = int(row_dict["month"])
    # return Q-learning expects (signature variables)
    return next_state, reward, next_row


# -----------------------------
# 7) Q-learning with Advanced Updates
# -----------------------------
def q_learning(
    ep_table: pd.DataFrame,
    demand_model,
    actions=(0.9, 1.0, 1.1),
    episodes=5000,
    horizon=20,
    alpha=0.1,
    gamma=0.9,
    epsilon=0.25,
    seed=0,
    update_method="double_q",  # "bellman", "double_q", "expected_sarsa", "n_step"
    n_step=3,  # for n-step returns
):
    """
    Tabular Q-learning with multiple update methods.
    
    Update Methods:
    - "bellman": Standard Q-learning (max over next state)
    - "double_q": Double Q-Learning (reduces maximization bias)
    - "expected_sarsa": Expected SARSA (uses expected value instead of max)
    - "n_step": N-step Q-learning (uses multi-step returns)
    """
    rng = np.random.default_rng(seed)

    actions = np.array(list(actions), dtype=float)
    n_states = 9
    n_actions = len(actions)
    
    if update_method == "double_q":
        # Double Q-Learning uses two Q-tables (2 separate estimates to reduce overestimation)
        Q1 = np.zeros((n_states, n_actions), dtype=float)
        Q2 = np.zeros((n_states, n_actions), dtype=float)
    else:
        Q = np.zeros((n_states, n_actions), dtype=float)

    # Loop over episodes and randomly sampled starting points
    # Goal: learn a pricing policy that maximizes EXPECTED long-term revenue across various products (states) and time periods
    for _ in range(episodes):
        # sample a random start row from ep_table 
        r = ep_table.iloc[int(rng.integers(0, len(ep_table)))].to_dict()
        # initial state is based on lagged demand, not current demand
        s = qty_bin(float(r["qty_lag1"]))
        
        # For n-step, store trajectory
        if update_method == "n_step":
            trajectory = []

        # Remark: we need to loop through the horizon steps because one episode in Q-learning can span multiple time steps
        #         Think of it as simulating a sequence of decisions within one episode to capture temporal dynamics
        #         Each step within the episode represents a decision point where the agent selects an action, observes the outcome, and updates its knowledge
        #         This allows the agent to learn from a sequence of interactions rather than a single decision
        #         Mind set: "Today's price decision affects not just today's revenue but also future states and rewards"
        #         Goal: learn a pricing policy that maximizes long-term revenue over multiple time steps NOT just immediate reward (revenue)
        # Mathematically, we are estimating:
        # Q[s,a] ~ E[
        #       sum_{t=0,...,infinity} \gamma^t reward_t | s0=s, a0=a
        # ]
        # That expectation is over a trajectory of states and rewards aka transitions
        # (s0,a0,reward0,s1) , (s1,a1,reward1,s2) , ...
        # Rule of thumb: effective horizon is roughly 1/(1-gamma)
        for t in range(horizon):
            # epsilon-greedy action selection:
            # given the current state s, available actions, current Q1,Q2 estimates
            # decide: try something new? or use what I've learnt so far
            #         with probability epsilon: explore (random action) and probability 1-epsilon: exploit (best known action)
            if update_method == "double_q":
                # Use average Q-values for action selection: this reduces variance, avoids trusting one noisy estimate, gives a more stable actions ranking
                q_avg = (Q1[s] + Q2[s]) / 2
                if rng.random() < epsilon:
                    a = int(rng.integers(0, n_actions))     # explore other action choice randomly
                else:
                    a = int(np.argmax(q_avg))               # use best-action, determined by largest Q-value from Q_avg table
            else:
                if rng.random() < epsilon:
                    a = int(rng.integers(0, n_actions))
                else:
                    a = int(np.argmax(Q[s]))
            # once we have chosen action a in actions list, we can simulate step
            # i.e., computing next state s2, reward and next row
            s2, reward, r = env_step(demand_model, r, actions[a])

            # ========== UPDATE RULES ==========
            
            if update_method == "bellman":
                # Standard Bellman Q-Learning:
                # Often overestimate due to using max() bias
                Q[s, a] = Q[s, a] + alpha * (reward + gamma * np.max(Q[s2]) - Q[s, a])
            
            elif update_method == "double_q":
                # Double Q-Learning: Randomly choose which Q to update
                # Double Q-learning reduce maximization bias
                if rng.random() < 0.5:
                    # Update Q1, use Q2 for evaluation
                    best_a = int(np.argmax(Q1[s2]))
                    target = reward + gamma * Q2[s2, best_a]
                    Q1[s, a] = Q1[s, a] + alpha * (target - Q1[s, a])
                else:
                    # Update Q2, use Q1 for evaluation
                    best_a = int(np.argmax(Q2[s2]))
                    target = reward + gamma * Q1[s2, best_a]
                    Q2[s, a] = Q2[s, a] + alpha * (target - Q2[s, a])
            
            elif update_method == "expected_sarsa":
                # Expected SARSA: Use expected value under current policy
                # Compute probability distribution over actions in s2
                if np.max(Q[s2]) > -1e10:  # if not all equal
                    # Epsilon-greedy probabilities
                    greedy_prob = 1.0 - epsilon + (epsilon / n_actions)
                    explore_prob = epsilon / n_actions
                    
                    probs = np.full(n_actions, explore_prob)
                    probs[np.argmax(Q[s2])] = greedy_prob
                    
                    expected_q = np.sum(probs * Q[s2])
                else:
                    expected_q = np.mean(Q[s2])
                
                Q[s, a] = Q[s, a] + alpha * (reward + gamma * expected_q - Q[s, a])
            
            elif update_method == "n_step":
                # N-step Q-Learning: Store trajectory and update when we have n steps
                trajectory.append((s, a, reward))
                
                if len(trajectory) >= n_step:
                    # Compute n-step return
                    G = 0.0
                    for i, (s_i, a_i, r_i) in enumerate(trajectory[-n_step:]):
                        G += (gamma ** i) * r_i
                    
                    # Add bootstrap value
                    G += (gamma ** n_step) * np.max(Q[s2])
                    
                    # Update the state-action from n steps ago
                    s_old, a_old, _ = trajectory[-n_step]
                    Q[s_old, a_old] = Q[s_old, a_old] + alpha * (G - Q[s_old, a_old])
            
            # update state vector
            s = s2
        
        # For n-step: update remaining states in trajectory
        if update_method == "n_step" and len(trajectory) > 0:
            for i in range(1, min(n_step, len(trajectory))):
                # Compute remaining returns
                G = 0.0
                for j in range(len(trajectory) - i, len(trajectory)):
                    s_j, a_j, r_j = trajectory[j]
                    G += (gamma ** (j - (len(trajectory) - i))) * r_j
                
                s_old, a_old, _ = trajectory[-(i+1)]
                Q[s_old, a_old] = Q[s_old, a_old] + alpha * (G - Q[s_old, a_old])

    # Return the appropriate Q-table
    if update_method == "double_q":
        # Average the two Q-tables for final policy
        Q = (Q1 + Q2) / 2
    # Return Q = this is a table storing learned long-term value of taking each pricing action in each demand state
    # Q[s,a] ~ E[
    #       sum_{t=0,...,infinity} \gamma^t reward_t | s0=s, a0=a, probability
    # ]
    # For example, Q can look like this
    # state (demand bin)	0.9×	1.0×	1.1×
    # 0 (q < 1)	            5.2	    6.8	    6.1
    # 1 (1 ≤ q < 5)	        12.1	13.4	12.9
    # 2 (5 ≤ q < 10)	    20.7	22.9	21.0
    # 3 (10 ≤ q < 15)	    33.0	35.8	34.2
    # 4 (15 ≤ q < 20)	    45.6	47.1	44.0
    # 5 (q ≥ 20)	        60.2	61.0	58.4
    # So if the predicted demand is in bin (5 ≤ q < 10), and if we choose action (1.0x)
    #    then the expected future revenue is ~ 22.9
    # When the demand is in bin (5 ≤ q < 10), we want to choose action having highest Q-values, in this case action (1.0x)
    return Q, actions


# A more robust version of Q-learning with reward transformation, Temporal-Difference clipping, adaptive learning rates, and target smoothing
def q_learning_robust(
    ep_table: pd.DataFrame,
    demand_model,
    actions=(0.9, 1.0, 1.1),
    episodes=5000,
    horizon=20,
    gamma=0.9,
    seed=0,
    update_method="double_q",     # "bellman" or "double_q"
    # exploration schedule
    epsilon_start=0.5,
    epsilon_end=0.05,
    epsilon_decay=0.999,
    # learning-rate schedule
    alpha0=0.5,                   # base LR; actual lr = alpha0 / sqrt(N(s,a)+1)
    # robustness knobs
    reward_transform="log1p",     # "none" or "log1p"
    td_clip=50.0,                 # clip TD error to [-td_clip, td_clip]
    # target smoothing (tabular "target network")
    use_target=True,
    tau=0.01,                     # Polyak rate for target tables
    # state space
    n_states=6                    # <-- set to match your qty_bin (0..5)
):
    rng = np.random.default_rng(seed)
    actions = np.array(list(actions), dtype=float)
    n_actions = len(actions)

    def transform_reward(r):
        if reward_transform == "log1p":
            return np.log1p(max(0.0, r))
        return float(r)

    # Visit counts for adaptive learning rates
    N_sa = np.zeros((n_states, n_actions), dtype=np.int64)

    if update_method == "double_q":
        # initialize Double Q-learning tables
        Q1 = np.zeros((n_states, n_actions), dtype=float)
        Q2 = np.zeros((n_states, n_actions), dtype=float)

        if use_target:
            # Note: Q1_t and Q2_t are slow-moving target copies for Double Q-learning tables
            #       They exist only to produce stable bootstrap targets.
            Q1_t = Q1.copy()
            Q2_t = Q2.copy()
    else:
        Q = np.zeros((n_states, n_actions), dtype=float)
        if use_target:
            Q_t = Q.copy()

    eps = float(epsilon_start)

    for ep in range(episodes):
        # decay epsilon, using a factor epsilon_decay = 0.999, for each episode
        eps = max(epsilon_end, eps * epsilon_decay)

        # sample a start row
        r = ep_table.iloc[int(rng.integers(0, len(ep_table)))].to_dict()
        s = int(qty_bin(float(r["qty_lag1"])))

        for t in range(horizon):
            # --- choose action (epsilon-greedy) ---
            if update_method == "double_q":
                q_beh = (Q1[s] + Q2[s]) / 2.0
            else:
                q_beh = Q[s]

            if rng.random() < eps:
                a = int(rng.integers(0, n_actions))
            else:
                a = int(np.argmax(q_beh))

            # --- simulate env step ---
            s2, reward, r = env_step(demand_model, r, actions[a])
            s2 = int(s2)

            # robust reward transformation (into log-scale). The goal is to stabilize learning by reducing variance in rewards
            r_t = transform_reward(reward)

            # adaptive learning rate for this (s,a)
            # a classic robust technique: reduce LR for frequently-visited (s,a) pairs
            # \alpha(s,a) = alpha0 / sqrt(N(s,a)+1)
            N_sa[s, a] += 1
            alpha = alpha0 / np.sqrt(N_sa[s, a])

            # ---------- compute bootstrap target ----------
            # Note: In Q-learning, we bootstrap from our own estimates of future value
            #       Bootstrap = targets are estimated using the model itself (not from actual observed rewards)
            #       Standard Q-learning uses TD target: r_t + gamma * max_a Q(s_{t+1},a) (notice the RHS uses Q)
            #       Double Q-learning uses TD target:   r_t + gamma * Q_other(s_{t+1}, argmax_a Q_self(s_{t+1},a))
            #       This bootstrapping allows us to learn long-term value without needing full episode returns
            if update_method == "double_q":
                # Use target tables for bootstrap if enabled
                if use_target:
                    # We will use the slow-moving target tables for evaluation
                    # We will NOT use it for choosing best actions (that would be too conservative) or for learning update.
                    Q1_eval = Q1_t
                    Q2_eval = Q2_t
                else:
                    Q1_eval = Q1
                    Q2_eval = Q2

                # Double-Q update (randomly update one table)
                if rng.random() < 0.5:
                    # select with Q1, evaluate with Q2
                    # This is where we do bootstrapping: and the bootstrap term is gamma * Q2_eval[s2, best_a]
                    # Bootstrapping mechanism:
                    # - We select best action best_a using Q1 (the table we are updating)
                    # - We evaluate that action using Q2_eval (the other table, possibly target table)
                    best_a = int(np.argmax(Q1[s2]))
                    target = r_t + gamma * Q2_eval[s2, best_a]  # evaluate with Q2 (bootstrap target)
                    delta = target - Q1[s, a]                   # compute TD error: if delta>0, we underestimated Q1[s,a] --> increase it
                                                                #                   if delta<0, we overestimated Q1[s,a]  --> decrease it
                    # clip TD error to stabilize learning (TD error can be very large due to heavy-tailed rewards)
                    if td_clip is not None:
                        delta = float(np.clip(delta, -td_clip, td_clip))
                    Q1[s, a] += alpha * delta
                else:
                    # select with Q2, evaluate with Q1 (similar reasoning as above)
                    best_a = int(np.argmax(Q2[s2]))
                    target = r_t + gamma * Q1_eval[s2, best_a]
                    delta = target - Q2[s, a]
                    if td_clip is not None:
                        delta = float(np.clip(delta, -td_clip, td_clip))
                    Q2[s, a] += alpha * delta

            else:
                # standard Q-learning
                if use_target:
                    bootstrap = np.max(Q_t[s2])
                else:
                    bootstrap = np.max(Q[s2])

                target = r_t + gamma * bootstrap
                delta = target - Q[s, a]
                if td_clip is not None:
                    delta = float(np.clip(delta, -td_clip, td_clip))
                Q[s, a] += alpha * delta

            # ---------- update targets (Polyak) ----------
            # Polyak averaging to slowly update target tables towards current Q estimates
            # It is a stability mechanism: by slowly tracking the learned Q-values, we reduce oscillations and divergence during learning
            # In other words, it makes bootstrapped Q-learning behave much better in noisy environments.
            # NOTE: Q-learning uses bootstrapped targets: target_t = r_t + gamma * Q(s_{t+1}, a)
            #       So if Q changes quickly, the targets also change quickly --> instability
            # Instead of bootstrapping from the latest Q, we use a smoothed version (target network)
            # Q_target = (1 - tau) * Q_target + tau * Q where tau is a small value like 0.01 or even 0.001.
            # Think of it as an exponential moving average of Q-values.
            if use_target and (t % 1 == 0):  # update every step (cheap for tabular)
                if update_method == "double_q":
                    Q1_t = (1.0 - tau) * Q1_t + tau * Q1
                    Q2_t = (1.0 - tau) * Q2_t + tau * Q2
                else:
                    Q_t = (1.0 - tau) * Q_t + tau * Q
            # Another way to think of this is that if tau = 0.01 then we use 99% of old target and 1% of new Q-values
            # Therefore, the target tables change very slowly over time, ensuring stability in learning

            s = s2

    if update_method == "double_q":
        Q_out = (Q1 + Q2) / 2.0
    else:
        Q_out = Q

    # Final Note:
    # - Double-Q learning helps reduce overestimation bias in Q-values
    # - Reward transformation (log1p) stabilizes learning by reducing variance in rewards
    # - TD clipping prevents extreme updates that can destabilize learning
    # - Adaptive learning rates ensure stable convergence by reducing step sizes for frequently-visited (s,a) pairs
    # - Target smoothing (Polyak averaging) stabilizes bootstrapped targets i.e., fixing bootstrap instability.
    return Q_out, actions

#--------------------------------------------------------------------------------------------------------------------------
# Here is the core idea:
# We are learning how actions change future states and how that affects long-term rewards
# We are NOT learning one Q-value per state.
# One episode represents a simulated short trajectory starting from a realistic state, sampled from historical data.
# Formally, we are generating: (s0,a0,r0,s1), (s1,a1,r1,s2), ... , (s_{H-1}, a_{H-1}, r_{H-1}, s_H) where H = number of horizon steps
# In very first step of horizon, we learn:
# - If demand is in bin s0, and we take action a0 (price multiplier), then we get reward r0 and transition to state s1
# In second step of horizon, we learn:
# - If demand is in bin s1, and we take action a1, then we get reward r1 and transition to state s2
# ...
# These steps together update Q(s,a) values for multiple (s,a) pairs within one episode
# Each TD (temporal-difference) update is:
# Q[s,a] = Q[s,a] + alpha * (target - Q[s,a]) where target = r + gamma * max_a' Q[s',a']
# This is done per horizon (not per episode)
# TD learning philosophy: as soon as I see one step of experience, I update my belief (Q-values about that (s,a) pair)
# So across one episode, we update:
# Q[s0,a0] based on (r0, s1)
# Q[s1,a1] based on (r1, s2)
# Q[s2,a2] based on (r2, s3)
# ...
# In summary,
# - During the horizon loop, the algorithm learns how today’s pricing action affects tomorrow’s demand state and future rewards, 
# allowing Q(s,a) to represent long-term value rather than just immediate revenue.
# - Episode loop, by sampling different starting states from historical data, ensures diverse experience and robust learning across the state space.
# I.e., episode loop teaches us about the EXPECTED long-term value of actions in various states.
#--------------------------------------------------------------------------------------------------------------------------



def extract_policy(Q, actions):
    """
    Return mapping: state -> best action multiplier
    policy[s] = argmax_a Q[s, a]
    In particular, we want to choose the action having highest Q-value for demand s, which is bin_id for state
    """
    best_a = np.argmax(Q, axis=1)
    return {s: float(actions[a]) for s, a in enumerate(best_a)}


def run_pipeline(top_k=200, seed=0, update_method="double_q"):
    """
    Run the full RL pricing pipeline.
    
    Args:
        top_k: Number of top products to include
        seed: Random seed
        update_method: Q-learning update rule ("bellman", "double_q", "expected_sarsa", "n_step")
    """
    TOP_PRODUCTS = make_top_products(data, top_k=top_k)
    episode_table = build_episode_table(data, TOP_PRODUCTS)
    demand_model = fit_demand_model(episode_table)
    # Q, actions = q_learning(
    #     episode_table,
    #     demand_model,
    #     actions=ACTION_MULTS,
    #     episodes=5000,
    #     horizon=20,
    #     alpha=0.1,
    #     gamma=0.95,
    #     epsilon=0.2,
    #     seed=seed,
    #     update_method=update_method,  # Use the specified update method
    #     n_step=3,  # For n-step method
    # )
    Q, actions = q_learning_robust(
        episode_table,
        demand_model,
        actions=ACTION_MULTS,
        episodes=5000,
        horizon=20,
        gamma=0.95,
        seed=seed,
        update_method=update_method,    # Use the specified update method
        epsilon_start=0.5,
        epsilon_end=0.05,
        epsilon_decay=0.9995,           # slower decay
        alpha0=0.5,
        reward_transform="log1p",
        td_clip=25.0,
        use_target=True,
        tau=0.01,
        n_states=9,  # Match qty_bin
    )
    policy = extract_policy(Q, actions)
    print(f"\n✓ Trained with update method: {update_method.upper()}")
    return policy, Q, actions, demand_model, episode_table

# Train with Double Q-Learning (recommended - reduces overestimation bias)
policy, Q, actions, demand_model, episode_table = run_pipeline(top_k=300, seed=42, update_method="double_q")
print("policy:", policy)
# Out:
# Demand model R^2 on log_qty: 0.423
#
# ✓ Trained with update method: DOUBLE_Q
# policy: {0: 0.9, 1: 1.2, 2: 0.9, 3: 1.1, 4: 1.2, 5: 0.9, 6: 1.0, 7: 1.2, 8: 1.2}

# %%
# Visualize the learned Q-table and policy
print("=" * 70)
print("LEARNED Q-TABLE")
print("=" * 70)
print(f"\nQ-table shape: {Q.shape}")
print(f"States: {Q.shape[0]} (quantity bins 0-5)")
print(f"Actions: {Q.shape[1]} (price multipliers)")
print(f"\nPrice multipliers: {actions}")
print(f"\nQ-values:")
print(Q)

print("\n" + "=" * 70)
print("LEARNED POLICY")
print("=" * 70)
print("\nState (qty_bin) -> Best Price Multiplier:")
for state, action_mult in policy.items():
    best_action_idx = np.argmax(Q[state])
    q_value = Q[state, best_action_idx]
    
    if state == 0:
        qty_range = "qty < 1"
    elif state == 1:
        qty_range = "1 ≤ qty < 10"
    elif state == 2:
        qty_range = "10 ≤ qty < 20"
    elif state == 3:
        qty_range = "20 ≤ qty < 30"
    elif state == 4:
        qty_range = "30 ≤ qty < 40"
    elif state == 5:
        qty_range = "40 ≤ qty < 50"
    elif state == 6:
        qty_range = "50 ≤ qty < 100"
    elif state == 7:
        qty_range = "100 ≤ qty < 200"
    else:
        qty_range = "qty ≥ 200"
    
    print(f"  State {state} ({qty_range:15s}): price × {action_mult:.2f} (Q-value: {q_value:.2f})")

print("\n" + "=" * 70)
print("POLICY INSIGHTS")
print("=" * 70)

# Count how many states prefer each action
action_preferences = {}
for state in range(Q.shape[0]):
    best_action = np.argmax(Q[state])
    mult = actions[best_action]
    action_preferences[mult] = action_preferences.get(mult, 0) + 1

print("\nPrice multiplier distribution:")
for mult in sorted(action_preferences.keys()):
    count = action_preferences[mult]
    pct = 100 * count / Q.shape[0]
    print(f"  {mult:.2f}x: {count} states ({pct:.1f}%)")
# Out:
# ======================================================================
# LEARNED Q-TABLE
# ======================================================================
#
# Q-table shape: (9, 8)
# States: 9 (quantity bins 0-5)
# Actions: 8 (price multipliers)
#
# Price multipliers: [0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25]
#
# Q-values:
# [[63.95562154 45.8930123  31.65927163 46.13666712 47.58273719 40.30694706
#   44.59289285 47.02747408]
#  [57.8355276  58.00855198 57.27276477 57.63903635 57.6587681  56.97481359
#   64.37071532 57.5369925 ]
#  [64.04779684 60.60496058 60.85838059 60.30358315 60.51260936 60.47138456
#   60.5816042  60.69021745]
#  [61.34587948 61.16537752 61.29569434 60.74565299 64.14180313 60.81840103
#   60.77385499 61.05161005]
#  [45.97509409 46.3011497  44.26561078 45.39323427 42.99500468 46.09343653
#   64.31897323 46.48732537]
#  [70.46928527 44.20950177 45.12127831 46.57489932 43.49714219 49.19616805
#   45.28103802 46.68721769]
#  [67.35367551 67.73071519 76.70902114 66.859777   66.0391439  66.48473741
#   65.81308145 65.25543947]
#  [36.65646131 45.37329474 42.77831143 43.60167438 47.76771467 47.65925629
#   71.89182217 38.04862773]
#  [35.04514222 39.27972364 27.74679668 33.61451076 34.67915397 42.35650803
#   70.42977459 41.87027911]]
#
# ======================================================================
# LEARNED POLICY
# ======================================================================
#
# State (qty_bin) -> Best Price Multiplier:
#   State 0 (qty < 1        ): price × 0.90 (Q-value: 63.96)
#   State 1 (1 ≤ qty < 10   ): price × 1.20 (Q-value: 64.37)
#   State 2 (10 ≤ qty < 20  ): price × 0.90 (Q-value: 64.05)
#   State 3 (20 ≤ qty < 30  ): price × 1.10 (Q-value: 64.14)
#   State 4 (30 ≤ qty < 40  ): price × 1.20 (Q-value: 64.32)
#   State 5 (40 ≤ qty < 50  ): price × 0.90 (Q-value: 70.47)
#   State 6 (50 ≤ qty < 100 ): price × 1.00 (Q-value: 76.71)
#   State 7 (100 ≤ qty < 200): price × 1.20 (Q-value: 71.89)
#   State 8 (qty ≥ 200      ): price × 1.20 (Q-value: 70.43)
#
# ======================================================================
# POLICY INSIGHTS
# ======================================================================
#
# Price multiplier distribution:
#   0.90x: 3 states (33.3%)
#   1.00x: 1 states (11.1%)
#   1.10x: 1 states (11.1%)
#   1.20x: 4 states (44.4%)

# %% [markdown]
# ### Remark:
# - Below evaluate_policy() uses un-paired t-test
# - This test assumes two samples are "independent", like:
#     - RL episodes are drawn from one population
#     - Baseline episodes are drawn from a different population
# - However, RL and baseline values are paired by construction:
#     - come from same row
#     - only action differs

# %%
# def evaluate_policy(Q, actions, episode_table, demand_model, n_eval=1000, seed=42):
#     """
#     Evaluate the learned pricing policy vs baseline strategies.
    
#     Args:
#         Q: Learned Q-table
#         actions: Array of action multipliers
#         episode_table: DataFrame with episode data
#         demand_model: Trained demand model
#         n_eval: Number of evaluation episodes
#         seed: Random seed for reproducibility
    
#     Returns:
#         Dictionary with evaluation metrics
#     """
#     rng = np.random.default_rng(seed)
    
#     # Storage for results
#     rl_revenues = []
#     baseline_revenues = []
#     rl_quantities = []
#     baseline_quantities = []
#     rl_prices = []
#     baseline_prices = []
    
#     for _ in range(n_eval):
#         # Sample random starting state
#         idx = int(rng.integers(0, len(episode_table)))
#         row = episode_table.iloc[idx].to_dict()
        
#         # Get state
#         state = qty_bin(float(row["qty_lag1"]))
#         base_price = float(row["price"])
        
#         # RL Policy: use learned Q-table
#         best_action = int(np.argmax(Q[state]))
#         rl_mult = float(actions[best_action])
#         rl_price = base_price * rl_mult
#         rl_qty = predict_qty(demand_model, row, rl_price)
#         rl_rev = rl_price * rl_qty
        
#         rl_revenues.append(rl_rev)
#         rl_quantities.append(rl_qty)
#         rl_prices.append(rl_price)
        
#         # Baseline: keep original price (1.0x multiplier)
#         baseline_qty = predict_qty(demand_model, row, base_price)
#         baseline_rev = base_price * baseline_qty
        
#         baseline_revenues.append(baseline_rev)
#         baseline_quantities.append(baseline_qty)
#         baseline_prices.append(base_price)
    
#     # Calculate metrics
#     results = {
#         'n_eval': n_eval,
#         'rl_avg_revenue': np.mean(rl_revenues),
#         'baseline_avg_revenue': np.mean(baseline_revenues),
#         'rl_avg_quantity': np.mean(rl_quantities),
#         'baseline_avg_quantity': np.mean(baseline_quantities),
#         'rl_avg_price': np.mean(rl_prices),
#         'baseline_avg_price': np.mean(baseline_prices),
#         'rl_revenues': rl_revenues,
#         'baseline_revenues': baseline_revenues,
#         'revenue_improvement_pct': 100 * (np.mean(rl_revenues) - np.mean(baseline_revenues)) / np.mean(baseline_revenues),
#         'rl_revenue_std': np.std(rl_revenues),
#         'baseline_revenue_std': np.std(baseline_revenues),
#     }
    
#     # Print evaluation results
#     print("=" * 70)
#     print("POLICY EVALUATION RESULTS")
#     print("=" * 70)
#     print(f"\nEvaluated on {n_eval:,} random episodes\n")
    
#     print("REVENUE:")
#     print(f"  Baseline (original prices): ${results['baseline_avg_revenue']:8.2f} (±${results['baseline_revenue_std']:.2f})")
#     print(f"  RL Policy:                  ${results['rl_avg_revenue']:8.2f} (±${results['rl_revenue_std']:.2f})")
#     print(f"  Improvement:                {results['revenue_improvement_pct']:+7.2f}%")
    
#     print("\nQUANTITY SOLD:")
#     print(f"  Baseline:  {results['baseline_avg_quantity']:6.2f} units")
#     print(f"  RL Policy: {results['rl_avg_quantity']:6.2f} units")
#     qty_change = 100 * (results['rl_avg_quantity'] - results['baseline_avg_quantity']) / results['baseline_avg_quantity']
#     print(f"  Change:    {qty_change:+6.2f}%")
    
#     print("\nAVERAGE PRICE:")
#     print(f"  Baseline:  ${results['baseline_avg_price']:6.2f}")
#     print(f"  RL Policy: ${results['rl_avg_price']:6.2f}")
#     price_change = 100 * (results['rl_avg_price'] - results['baseline_avg_price']) / results['baseline_avg_price']
#     print(f"  Change:    {price_change:+6.2f}%")
    
#     # Statistical test
#     from scipy import stats
#     t_stat, p_value = stats.ttest_ind(rl_revenues, baseline_revenues)
#     print(f"\nSTATISTICAL SIGNIFICANCE:")
#     print(f"  t-statistic: {t_stat:.3f}")
#     print(f"  p-value:     {p_value:.6f}")
#     if p_value < 0.05:
#         print(f"  Result:      Statistically significant (p < 0.05) ✓")
#     else:
#         print(f"  Result:      Not statistically significant (p ≥ 0.05)")
    
#     # Distribution analysis
#     print(f"\nREVENUE DISTRIBUTION:")
#     print(f"  Baseline - Min: ${np.min(baseline_revenues):.2f}, Max: ${np.max(baseline_revenues):.2f}, Median: ${np.median(baseline_revenues):.2f}")
#     print(f"  RL Policy - Min: ${np.min(rl_revenues):.2f}, Max: ${np.max(rl_revenues):.2f}, Median: ${np.median(rl_revenues):.2f}")
    
#     # Win rate
#     wins = sum(1 for rl, bl in zip(rl_revenues, baseline_revenues) if rl > bl)
#     win_rate = 100 * wins / n_eval
#     print(f"\nWIN RATE:")
#     print(f"  RL Policy beats baseline in {wins}/{n_eval} episodes ({win_rate:.1f}%)")
    
#     return results


# # Run evaluation
# eval_results = evaluate_policy(Q, actions, episode_table, demand_model, n_eval=20000, seed=42)

# %% [markdown]
# ### Remark:
# - Correct statistical test must be used is the Paired t-test
# - We also observed that quantity demand is heavily tailed --> revenue will also be heavily tailed by construction
# - In other words, revenue becomes skewed with outliers
# - A lession:
#     - classic t-test is sensitive to outlier, non-normalities, ...
#     - Need to use paired-testing & robust test for heavy tails (Wilcoxon signed-rank test)
# - Paired test: works because RL & baseline are computed from same row: they are not independent as assumed by unpaired test
# - Wilcoxon signed-rank test: more robust to heavy tails
# - Sign test/Binomial test (for win-rate): answer YES/NO to does RL beat baseline.
#     - So if p-value for this test ~ 0 ==> YES! RL beat baseline with statistically significant confidence

# %%
import numpy as np
import pandas as pd

def evaluate_policy(Q, actions, episode_table, demand_model, n_eval=5000, seed=420, do_bootstrap=True, n_boot=2000):
    """
    Evaluate the learned pricing policy vs baseline strategies with robust statistical tests.

    Adds:
      - Paired t-test (ttest_rel)
      - Wilcoxon signed-rank test (wilcoxon)
      - Sign test via binomial test on win rate (binomtest)
      - (Optional) Bootstrap CI for mean/median revenue lift
    """
    rng = np.random.default_rng(seed)

    rl_revenues = []
    baseline_revenues = []
    rl_quantities = []
    baseline_quantities = []
    rl_prices = []
    baseline_prices = []

    for _ in range(n_eval):
        # mimic of what we are doing in q_learning() function
        idx = int(rng.integers(0, len(episode_table)))
        row = episode_table.iloc[idx].to_dict()

        state = qty_bin(float(row["qty_lag1"])) # current state is demand quantity lag1
        base_price = float(row["price"])        # extract base price of current state

        # RL Policy
        best_action = int(np.argmax(Q[state]))  # for Q[s,a], we extract best a (action) for each discrete state
        rl_mult = float(actions[best_action])   # extract RL's price multipliers according to best action
        rl_price = base_price * rl_mult         # update RL price = base * multiplier-factor
        rl_qty = predict_qty(demand_model, row, rl_price)   # using RL-price, predict demand
        rl_rev = rl_price * rl_qty              # compute reward function using RL's recommended price and predicted demand quantity

        rl_revenues.append(rl_rev)              # store revenues, predicted quantity and RL recommended price into vectors
        rl_quantities.append(rl_qty)
        rl_prices.append(rl_price)

        # Baseline: baseline decision is basically using base_price without any multiplier (i.e. multiplier = 1x)
        baseline_qty = predict_qty(demand_model, row, base_price)
        baseline_rev = base_price * baseline_qty

        baseline_revenues.append(baseline_rev)
        baseline_quantities.append(baseline_qty)
        baseline_prices.append(base_price)

    rl_revenues = np.asarray(rl_revenues, dtype=float)
    baseline_revenues = np.asarray(baseline_revenues, dtype=float)

    # Core metrics
    rl_mean = float(np.mean(rl_revenues))
    bl_mean = float(np.mean(baseline_revenues))
    rl_std = float(np.std(rl_revenues, ddof=1))
    bl_std = float(np.std(baseline_revenues, ddof=1))

    revenue_improvement_pct = 100.0 * (rl_mean - bl_mean) / (bl_mean + 1e-12)

    results = {
        "n_eval": n_eval,
        "rl_avg_revenue": rl_mean,
        "baseline_avg_revenue": bl_mean,
        "rl_avg_quantity": float(np.mean(rl_quantities)),
        "baseline_avg_quantity": float(np.mean(baseline_quantities)),
        "rl_avg_price": float(np.mean(rl_prices)),
        "baseline_avg_price": float(np.mean(baseline_prices)),
        "rl_revenue_std": rl_std,
        "baseline_revenue_std": bl_std,
        "revenue_improvement_pct": revenue_improvement_pct,
        "rl_revenues": rl_revenues,
        "baseline_revenues": baseline_revenues,
    }

    # -----------------------------
    # Statistical tests
    # -----------------------------
    from scipy import stats

    diff = rl_revenues - baseline_revenues  # compute difference between RL's reward and baseline's reward functions

    # 1) Paired t-test (recommended)
    t_rel, p_rel = stats.ttest_rel(rl_revenues, baseline_revenues)

    # 2) Wilcoxon signed-rank test (paired, nonparametric)
    # Wilcoxon requires non-all-zero diffs; handle edge case safely
    if np.allclose(diff, 0.0):
        w_stat, p_wil = np.nan, 1.0
    else:
        # zero_method='wilcox' ignores zero diffs; alternative='greater' tests RL > baseline
        try:
            w_stat, p_wil = stats.wilcoxon(diff, zero_method="wilcox", alternative="greater")
        except TypeError:
            # Older SciPy may not support 'alternative'; fall back to two-sided
            w_stat, p_wil = stats.wilcoxon(diff, zero_method="wilcox")

    # 3) Sign test via Binomial test on win-rate (paired, very robust)
    # this can be done by calculate number of wins: a win is defined by positive difference in (rl - baseline) revenues
    wins = int(np.sum(diff > 0))
    ties = int(np.sum(diff == 0))
    # Exclude ties for the sign test (standard approach)
    n_eff = n_eval - ties
    if n_eff > 0:
        p_sign = stats.binomtest(wins, n_eff, 0.5, alternative="greater").pvalue
    else:
        p_sign = 1.0

    # 4) (Optional) Bootstrap CI for mean/median lift (paired resampling)
    boot_ci = None
    if do_bootstrap:
        idxs = np.arange(n_eval)
        boot_means = np.empty(n_boot, dtype=float)
        boot_medians = np.empty(n_boot, dtype=float)
        for b in range(n_boot):
            samp = rng.choice(idxs, size=n_eval, replace=True)
            d = diff[samp]
            boot_means[b] = np.mean(d)
            boot_medians[b] = np.median(d)

        boot_ci = {
            "mean_diff": float(np.mean(diff)),
            "mean_diff_ci95": (float(np.quantile(boot_means, 0.025)), float(np.quantile(boot_means, 0.975))),
            "median_diff": float(np.median(diff)),
            "median_diff_ci95": (float(np.quantile(boot_medians, 0.025)), float(np.quantile(boot_medians, 0.975))),
        }

    # Save stats in results
    results["stats"] = {
        "paired_ttest": {"t": float(t_rel), "p": float(p_rel)},
        "wilcoxon": {"stat": float(w_stat) if not np.isnan(w_stat) else np.nan, "p": float(p_wil)},
        "sign_test_binom": {"wins": wins, "ties": ties, "n_eff": n_eff, "p": float(p_sign)},
        "bootstrap_ci": boot_ci,
    }

    # -----------------------------
    # Print results
    # -----------------------------
    print("=" * 70)
    print("POLICY EVALUATION RESULTS")
    print("=" * 70)
    print(f"\nEvaluated on {n_eval:,} random episodes\n")

    print("REVENUE:")
    print(f"  Baseline (original prices): ${bl_mean:8.2f} (±${bl_std:,.2f})")
    print(f"  RL Policy:                  ${rl_mean:8.2f} (±${rl_std:,.2f})")
    print(f"  Improvement:                {revenue_improvement_pct:+7.2f}%")

    print("\nQUANTITY SOLD:")
    print(f"  Baseline:  {results['baseline_avg_quantity']:6.2f} units")
    print(f"  RL Policy: {results['rl_avg_quantity']:6.2f} units")
    qty_change = 100 * (results["rl_avg_quantity"] - results["baseline_avg_quantity"]) / (results["baseline_avg_quantity"] + 1e-12)
    print(f"  Change:    {qty_change:+6.2f}%")

    print("\nAVERAGE PRICE:")
    print(f"  Baseline:  ${results['baseline_avg_price']:6.2f}")
    print(f"  RL Policy: ${results['rl_avg_price']:6.2f}")
    price_change = 100 * (results["rl_avg_price"] - results["baseline_avg_price"]) / (results["baseline_avg_price"] + 1e-12)
    print(f"  Change:    {price_change:+6.2f}%")

    print("\nSTATISTICAL SIGNIFICANCE (recommended for your setup):")
    print(f"  Paired t-test (mean diff):      t={t_rel:.3f}, p={p_rel:.6f}")
    print(f"  Wilcoxon (median/robust):       stat={w_stat:.3f}, p={p_wil:.6f}")
    print(f"  Sign test (win-rate, robust):   wins={wins}/{n_eff} (ties={ties}), p={p_sign:.6g}")

    if do_bootstrap and boot_ci is not None:
        lo, hi = boot_ci["mean_diff_ci95"]
        mlo, mhi = boot_ci["median_diff_ci95"]
        print("\nBOOTSTRAP 95% CI (paired):")
        print(f"  Mean revenue lift:   {boot_ci['mean_diff']:.3f}  CI[{lo:.3f}, {hi:.3f}]")
        print(f"  Median revenue lift: {boot_ci['median_diff']:.3f}  CI[{mlo:.3f}, {mhi:.3f}]")

    print("\nREVENUE DISTRIBUTION:")
    print(f"  Baseline - Min: ${np.min(baseline_revenues):.2f}, Max: ${np.max(baseline_revenues):.2f}, Median: ${np.median(baseline_revenues):.2f}")
    print(f"  RL Policy - Min: ${np.min(rl_revenues):.2f}, Max: ${np.max(rl_revenues):.2f}, Median: ${np.median(rl_revenues):.2f}")

    win_rate = 100.0 * wins / max(1, n_eff)
    print("\nWIN RATE:")
    print(f"  RL Policy beats baseline in {wins}/{n_eff} episodes ({win_rate:.1f}%)")

    return results

eval_results = evaluate_policy(Q, actions, episode_table, demand_model, n_eval=5000, seed=42)
# Out:
# ======================================================================
# POLICY EVALUATION RESULTS
# ======================================================================
#
# Evaluated on 5,000 random episodes
#
# REVENUE:
#   Baseline (original prices): $   74.77 (±$482.30)
#   RL Policy:                  $   77.98 (±$520.38)
#   Improvement:                  +4.30%
#
# QUANTITY SOLD:
#   Baseline:   35.94 units
#   RL Policy:  34.23 units
#   Change:     -4.76%
#
# AVERAGE PRICE:
#   Baseline:  $  2.44
#   RL Policy: $  2.56
#   Change:     +5.01%
#
# STATISTICAL SIGNIFICANCE (recommended for your setup):
#   Paired t-test (mean diff):      t=5.630, p=0.000000
#   Wilcoxon (median/robust):       stat=7267662.000, p=0.000000
#   Sign test (win-rate, robust):   wins=3118/4383 (ties=617), p=5.8765e-178
#
# BOOTSTRAP 95% CI (paired):
#   Mean revenue lift:   3.212  CI[2.216, 4.495]
#   Median revenue lift: 0.829  CI[0.781, 0.874]
#
# REVENUE DISTRIBUTION:
#   Baseline - Min: $0.00, Max: $18002.38, Median: $24.92
#   RL Policy - Min: $0.00, Max: $19570.42, Median: $25.52
#
# WIN RATE:
#   RL Policy beats baseline in 3118/4383 episodes (71.1%)

# %% [markdown]
# ### Visualize Evaluation Results

# %%
# Create visualization of evaluation results
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Revenue Comparison Histogram
ax1 = axes[0, 0]
ax1.hist(eval_results['baseline_revenues'], bins=100, alpha=0.6, label='Baseline', color='blue', edgecolor='black')
ax1.hist(eval_results['rl_revenues'], bins=100, alpha=0.6, label='RL Policy', color='green', edgecolor='black')
ax1.axvline(eval_results['baseline_avg_revenue'], color='blue', linestyle='--', linewidth=2, label=f'Baseline Avg: ${eval_results["baseline_avg_revenue"]:.2f}')
ax1.axvline(eval_results['rl_avg_revenue'], color='green', linestyle='--', linewidth=2, label=f'RL Avg: ${eval_results["rl_avg_revenue"]:.2f}')
ax1.set_xlim([0.0, 2000.0])
ax1.set_xlabel('Revenue ($)', fontsize=12)
ax1.set_ylabel('Frequency', fontsize=12)
ax1.set_title('Revenue Distribution Comparison', fontsize=14, fontweight='bold')
ax1.legend()
ax1.grid(alpha=0.3)

# 2. Scatter plot: RL vs Baseline Revenue
ax2 = axes[0, 1]
ax2.scatter(eval_results['baseline_revenues'], eval_results['rl_revenues'], alpha=0.5, s=20)
max_rev = max(max(eval_results['baseline_revenues']), max(eval_results['rl_revenues']))
min_rev = min(min(eval_results['baseline_revenues']), min(eval_results['rl_revenues']))
ax2.plot([min_rev, max_rev], [min_rev, max_rev], 'r--', linewidth=2, label='Equal Revenue Line')
ax2.set_xscale("log")
ax2.set_yscale("log")
ax2.set_xlabel('Baseline Revenue ($)', fontsize=12)
ax2.set_ylabel('RL Policy Revenue ($)', fontsize=12)
ax2.set_title('RL vs Baseline Revenue (per episode)', fontsize=14, fontweight='bold')
ax2.legend()
ax2.grid(alpha=0.3)

# Add text showing win rate
effective_win_rate = 100.0 * eval_results['stats']['sign_test_binom']['wins'] / max(1, eval_results['stats']['sign_test_binom']['n_eff'])
ax2.text(0.05, 0.95, f'Effective RL Wins (Excluding Ties): {effective_win_rate:.1f}%', transform=ax2.transAxes, 
         fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

# 3. Q-value heatmap
ax3 = axes[1, 0]
im = ax3.imshow(Q, aspect='auto', cmap='RdYlGn', interpolation='nearest')
ax3.set_xlabel('Action (Price Multiplier)', fontsize=12)
ax3.set_ylabel('State (Quantity Bin)', fontsize=12)
ax3.set_title('Learned Q-Values Heatmap', fontsize=14, fontweight='bold')
ax3.set_xticks(range(len(actions)))
ax3.set_xticklabels([f'{a:.2f}x' for a in actions])
ax3.set_yticks(range(Q.shape[0]))
ax3.set_yticklabels([f'State {i}' for i in range(Q.shape[0])])
plt.colorbar(im, ax=ax3, label='Q-value')

# Add annotations for best actions
for i in range(Q.shape[0]):
    for j in range(Q.shape[1]):
        text = ax3.text(j, i, f'{Q[i, j]:.1f}',
                       ha="center", va="center", color="black", fontsize=9)

# 4. Bar chart: Average metrics comparison
ax4 = axes[1, 1]
metrics = ['Revenue', 'Quantity', 'Price']
baseline_vals = [
    eval_results['baseline_avg_revenue'],
    eval_results['baseline_avg_quantity'],
    eval_results['baseline_avg_price']
]
rl_vals = [
    eval_results['rl_avg_revenue'],
    eval_results['rl_avg_quantity'],
    eval_results['rl_avg_price']
]

x = np.arange(len(metrics))
width = 0.35

bars1 = ax4.bar(x - width/2, baseline_vals, width, label='Baseline', color='blue', alpha=0.7)
bars2 = ax4.bar(x + width/2, rl_vals, width, label='RL Policy', color='green', alpha=0.7)

ax4.set_xlabel('Metric', fontsize=12)
ax4.set_ylabel('Value', fontsize=12)
ax4.set_title('Average Metrics Comparison', fontsize=14, fontweight='bold')
ax4.set_xticks(x)
ax4.set_xticklabels(metrics)
ax4.legend()
ax4.grid(alpha=0.3, axis='y')

# Add value labels on bars
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        ax4.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.1f}',
                ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

print("\n" + "=" * 70)
print("VISUALIZATION COMPLETE")
print("=" * 70)
# Out:
# ======================================================================
# VISUALIZATION COMPLETE
# ======================================================================

# %% [markdown]
# ### Deep Q-learning

# %% [markdown]
# ### From Tabular to Deep Q-Learning
#
# **Key Differences:**
#
# | Aspect | Tabular Q-Learning | Deep Q-Learning (DQN) |
# |--------|-------------------|----------------------|
# | **State Representation** | Discrete bins (0-8) | Continuous features |
# | **Q-Values Storage** | Table: Q[state, action] | Neural Network: Q(s,a;θ) |
# | **State Space** | Limited (9 states) | Unlimited (handles high-dim) |
# | **Generalization** | None (each state separate) | Learns patterns across states |
# | **Memory** | None needed | Experience Replay Buffer |
#
# **Why Deep Q-Learning?**
# 1. **Continuous States**: No need to discretize qty_lag1, qty_lag7, price, etc.
# 2. **Generalization**: If Q(qty_lag1=10, price=5) is good, network learns similar states have similar values
# 3. **Scalability**: Can add more features (seasonality, competitor prices, etc.) without exponential growth
# 4. **Feature Learning**: Network automatically learns useful representations
#
# **Key Components of DQN:**
# 1. **Neural Network** Q(s,a;θ): Maps state → Q-values for all actions
# 2. **Experience Replay**: Store (s,a,r,s') transitions, sample randomly for training
# 3. **Target Network** Q(s,a;θ⁻): Slow-moving copy for stable targets
# 4. **Loss Function**: Huber / MSE between predicted Q and target Q

# %%
# Install PyTorch if needed
# %pip install torch torchvision torchaudio --quiet
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque
import random

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# PyTorch version: 2.10.0.dev20251014
# CUDA available: False
# Using device: cpu

# %%
# =========================
# STABLE DQN SETUP (TABULAR PRICING)
# =========================

import math
import random
from collections import deque

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# -------------------------
# 1) State preprocessing: dict -> np.float32 vector (23 dims)
# -------------------------

STATE_DIM = 23  # 4 numerical + 7 dow + 12 month
                # 4 numerical: log(price), qty_lag1, qty_lag7, n_txn

def state_to_vec(row_dict):
    """
    Convert state dict -> numpy float32 vector (23,).
    Uses safe transforms + clipping to stabilize training.
    """
    price = float(row_dict["price"])
    qty_lag1 = float(row_dict["qty_lag1"])
    qty_lag7 = float(row_dict["qty_lag7"])
    n_txn = float(row_dict["n_txn"])

    # Safe clamps
    log_price = np.log(np.clip(price, 1e-6, 1e6))
    qty_lag1 = np.clip(qty_lag1, 0.0, 1e6)
    qty_lag7 = np.clip(qty_lag7, 0.0, 1e6)
    n_txn = np.clip(n_txn, 0.0, 1e6)

    # Fixed scaling (better: fit mean/std from data, but this is stable enough)
    numerical = np.array([
        log_price / 10.0,
        qty_lag1 / 200.0,
        qty_lag7 / 200.0,
        n_txn / 20.0
    ], dtype=np.float32)
    numerical = np.clip(numerical, -5.0, 5.0).astype(np.float32)

    # Perform one-hot-encode for DOW
    dow = int(row_dict["dow"]) % 7                  # dow or dayofweek: 0=Sun, 1=Mon, ..., 6=Sat
    dow_onehot = np.zeros(7, dtype=np.float32)
    dow_onehot[dow] = 1.0

    # Perform one-hot-encode for month
    month = int(row_dict["month"])                  # month: 1=Jan, 2=Feb, ..., 12=Dec
    month = max(1, min(12, month))
    month_onehot = np.zeros(12, dtype=np.float32)
    month_onehot[month - 1] = 1.0

    vec = np.concatenate([numerical, dow_onehot, month_onehot]).astype(np.float32)
    assert vec.shape[0] == STATE_DIM
    # For each row in the episode table, we convert it to a state vector of shape (23,)
    return vec


# -------------------------
# 2) Replay Buffer: tensor-ready, reward scaling/clipping
# -------------------------

class ReplayBuffer:
    def __init__(self, capacity=200_000, reward_scale=1/1000, reward_clip=None):
        self.buffer = deque(maxlen=capacity)        # capacity = maximum transitions to store in replay memory.
                                                    # when buffer is full, the oldest transitions are discarded and is replaced by new transitions.
        self.reward_scale = float(reward_scale)
        self.reward_clip = reward_clip  # e.g. 10.0 or None

    def push(self, state_vec, action, reward, next_state_vec, done):
        """
        Taking one transition (s, a, r, s', d),
        - normalize state vectors to float32 np.arrays: ensure consistent numeric type, avoid python list, and match torch tensor dtype later
        - scale/clip reward: DQN loss scales with reward magnitude, so scaling helps stability i.e., avoid Q-value explosion, gradient explosion,...
                             clipping also helps avoid large TD errors/variance that destabilize training
        - store in buffer as tuple
        - done: float (0.0 or 1.0) for easier tensor conversion later
                1.0 = no bootstrap, 0.0 = normal TD update
                target is: y_t = r_t + (1 - done_t) * gamma * max_a Q(s_{t+1}, a)
                               = reward + (1 - done)* gamma * next_Q
            So if done=1, agent learns: this reward is the final reward, no future Q
                  done=0, agent learns: this reward is part of a longer trajectory.
        """
        s = np.asarray(state_vec, dtype=np.float32)
        ns = np.asarray(next_state_vec, dtype=np.float32)

        r = float(reward) * self.reward_scale
        if self.reward_clip is not None:
            r = float(np.clip(r, -self.reward_clip, self.reward_clip))

        a = int(action)
        d = float(done)

        self.buffer.append((s, a, r, ns, d))

    def sample(self, batch_size, device=None):
        """
        Randomly sample a batch of transitions, convert to torch tensors.
        If device is specified, move tensors to GPU.
        1) Sample batch from buffer
        2) Unzip into components
        3) Stack/convert to np.arrays with correct dtypes
        4) Convert to torch tensors
        5) (Optional) Move to GPU
        6) Return tensors
        7) Each tensor shape:
           - states: (batch_size, state_dim)
           - actions: (batch_size,)
           - rewards: (batch_size,)
           - next_states: (batch_size, state_dim)
           - dones: (batch_size,)
        """
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = np.stack(states).astype(np.float32)
        next_states = np.stack(next_states).astype(np.float32)
        actions = np.asarray(actions, dtype=np.int64)
        rewards = np.asarray(rewards, dtype=np.float32)
        dones = np.asarray(dones, dtype=np.float32)

        states_t = torch.from_numpy(states)
        next_states_t = torch.from_numpy(next_states)
        actions_t = torch.from_numpy(actions)
        rewards_t = torch.from_numpy(rewards)
        dones_t = torch.from_numpy(dones)

        # if cuda device, move tensors to GPU
        if device is not None:
            states_t = states_t.to(device, non_blocking=True)
            next_states_t = next_states_t.to(device, non_blocking=True)
            actions_t = actions_t.to(device, non_blocking=True)
            rewards_t = rewards_t.to(device, non_blocking=True)
            dones_t = dones_t.to(device, non_blocking=True)

        return states_t, actions_t, rewards_t, next_states_t, dones_t

    def __len__(self):
        return len(self.buffer)


# -------------------------
# 3) Q-Network: stable MLP + (optional) Dueling head
# -------------------------
class DQN(nn.Module):
    def __init__(self, state_dim, n_actions, hidden_dims=(256, 256), use_dueling=True):
        super().__init__()
        self.use_dueling = use_dueling
        self.n_actions = n_actions

        dims = (state_dim,) + tuple(hidden_dims)        # construct a list of layer sizes, starting from the input.
                                                        # since in this example, we have 23 features (state_dim), then hidden layers, e.g. (256, 256)
                                                        # ==> dims = (23, 256, 256)

        # The Use of ModuleList, acts like PythonList, allows us to create a list of layers that can be iterated over in the forward pass.
        # Ensures; parameters are registered properly in model.parameters() for optimization.
        #          gradients flow correctly during backpropagation.
        self.fcs = nn.ModuleList()
        self.lns = nn.ModuleList()
        # Build Linear + LayerNorm layers
        # For this example, the structure will be:
        # Layer 1: Linear(23 -> 256) + LayerNorm(256)
        # Layer 2: Linear(256 -> 256) + LayerNorm(256)
        # Note: LayerNorm helps stabilize training by normalizing activations. It is better than BatchNorm for RL tasks.
        for in_d, out_d in zip(dims[:-1], dims[1:]):
            self.fcs.append(nn.Linear(in_d, out_d))
            self.lns.append(nn.LayerNorm(out_d))

        # Implementation of dueling DQN architecture
        # Dueling DQN separates the estimation of state-value function V(s) and advantage function A(s,a).
        # This helps the network learn which states are (or are not) valuable,
        # without having to learn the effect of each action for each state.
        # I.e., it separates "how good is this state?" from "how much better is this action compared to others in this state?"
        if use_dueling:
            # Dueling DQN: separate value and advantage streams: Q(s,a) = V(s) + A(s,a)
            # V(s): value of being in state s
            # A(s,a): advantage of taking action a in state s relative to other actions
            # This separation improves:
            # - learning stability
            # - sample efficiency
            # - generalization across actions
            self.value = nn.Sequential(
                nn.Linear(dims[-1], dims[-1]),
                nn.ReLU(),
                nn.Linear(dims[-1], 1)
            )   # This network computes V(s) \in R:  high-demand states have high V(s), low-demand states have low V(s)
            self.adv = nn.Sequential(
                nn.Linear(dims[-1], dims[-1]),
                nn.ReLU(),
                nn.Linear(dims[-1], n_actions)
            )   # This network computes A(s,a) \in R^{n_actions}:  for each action, how much better/worse it is compared to average action in state s
        else:
            # standard DQN learn Q(s,a) directly so output is (n_actions,)
            self.q = nn.Linear(dims[-1], n_actions)

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_uniform_(m.weight, a=0.01, nonlinearity="relu")
                nn.init.zeros_(m.bias)

        # Small last-layer init prevents early Q explosions
        if self.use_dueling:
            for head in [self.value, self.adv]:
                last = head[-1]
                nn.init.uniform_(last.weight, -1e-3, 1e-3)
                nn.init.zeros_(last.bias)
        else:
            nn.init.uniform_(self.q.weight, -1e-3, 1e-3)
            nn.init.zeros_(self.q.bias)

    def forward(self, x):
        # stacking layers like this: FC + LayerNorm + ReLU
        for fc, ln in zip(self.fcs, self.lns):
            x = F.relu(ln(fc(x)))
        # For example, if hidden_dims = [256, 256], architecture is:
        # Input (23) -> Linear(23 -> 256) + LayerNorm(256) + ReLU -> Linear(256 -> 256) + LayerNorm(256) + ReLU

        # If using dueling DQN architecture, at the end of the above ReLU layer, we stack:
        # V + [A - mean(A)]
        if self.use_dueling:
            v = self.value(x)
            a = self.adv(x)
            return v + (a - a.mean(dim=1, keepdim=True))
        else:
            return self.q(x)
        # architecture is:
        # ReLU output -> (if dueling) V(s) + [A(s,a) - mean(A(s,a))]  OR  (if standard) Linear(256 -> n_actions)
        #---------------------------------------------------------------------------------
        # Input: state (B, state_dim),                                              where B = batch size
        #     |
        #     +--> Linear(state_dim -> 256) -> LayerNorm(256) -> ReLU
        #     |
        #     +--> Linear(256 -> 256)       -> LayerNorm(256) -> ReLU
        #     |
        #     Features f (B, 256)
        #     |
        #     +--> Value head:
        #     |      Linear(256 -> 256) -> ReLU -> Linear(256 -> 1)   = V(s) (B,1)
        #     |
        #     +--> Advantage head:
        #             Linear(256 -> 256) -> ReLU -> Linear(256 -> A)   = A(s,a) (B,A)
        #---------------------------------------------------------------------------------
        # Output shape: (batch_size, n_actions)
        # Q(s,a) = V(s) + (A(s,a) - mean_a A(s,a))    -> (B, A)



# -------------------------
# 4) DQNAgent: Double DQN + step-based epsilon + target updates by grad steps
# -------------------------

class DQNAgent:
    def __init__(
        self,
        state_dim,
        n_actions,
        actions_array,
        hidden_dims=(256, 256),
        lr=1e-4,
        gamma=0.97,
        eps_start=1.0,
        eps_end=0.05,
        eps_decay_steps=80_000,     # decay over env steps
        buffer_capacity=200_000,
        batch_size=128,
        target_update_steps=5_000,  # hard update every N grad steps
        tau=None,                   # set to 0.005 for soft update instead of hard
        use_dueling=True,
        reward_scale=1/1000,
        reward_clip=None,
        device="cuda"
    ):
        self.state_dim = state_dim
        self.n_actions = n_actions
        self.actions_array = actions_array
        self.gamma = gamma
        self.batch_size = batch_size
        self.device = device

        self.eps_start = eps_start
        self.eps_end = eps_end
        self.eps_decay_steps = eps_decay_steps

        # We need two networks for Double DQN:
        # 1) policy_net: used to select actions (argmax_a Q(s,a))
        # 2) target_net: used to compute target Q-values for TD updates
        # The target we train against does not move at the same time as the policy net, which stabilizes training.
        # I.e., if we only use one network, the learning target keep changing while we are trying to chase it, leading to instability.
        # So:
        # in policy_net: select action, compute Q-values --> parameters change every grad step
        # in target_net: compute target Q-values --> parameters change slowly (every N steps/episodes) -- almost frozen.
        # If we only use a single network for computing Q(s,a) and computing max_a Q(s',a), the moving target problem can lead to divergence due to:
        # - update \theta
        # - which immediately changes TemporalDifference (TD) target: y = r + \gamma * max_a Q(s',a; \theta)
        # - which changes loss landscape
        # - leading to oscillations or divergence.
        self.policy_net = DQN(state_dim, n_actions, hidden_dims=hidden_dims, use_dueling=use_dueling).to(device)
        self.target_net = DQN(state_dim, n_actions, hidden_dims=hidden_dims, use_dueling=use_dueling).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)

        self.replay_buffer = ReplayBuffer(
            capacity=buffer_capacity,
            reward_scale=reward_scale,
            reward_clip=reward_clip
        )

        self.target_update_steps = target_update_steps
        self.tau = tau

        self.steps_done = 0   # env steps
        self.grad_steps = 0   # optimizer steps

    def epsilon_by_step(self):
        """
        Implements linear epsilon decay over steps.
        REMARK: Epsilon controls the exploration-exploitation trade-off.
                Higher epsilon = more exploration (random actions)
                Lower epsilon = more exploitation (greedy actions)
        1. Start with high epsilon (eps_start) to encourage exploration.
        2. Linearly decay epsilon to eps_end over eps_decay_steps.
        3. After eps_decay_steps, epsilon remains at eps_end.
        4. This helps the agent explore sufficiently early on, then exploit learned policy later.
        5. This is a simple yet effective strategy for balancing exploration and exploitation in DQN.
        6. More advanced strategies (e.g., exponential decay, adaptive methods) can be used but linear decay is a good baseline.
        7. Returns current epsilon value based on steps done.
        8. Used in select_action() to decide between random action vs. greedy action.
        9. Epsilon decay helps prevent premature convergence to suboptimal policies.
        10. Ensures sufficient exploration of state-action space during training.
        11. Helps avoid overfitting to early experiences in replay buffer.
        12. Overall, linear epsilon decay is a simple and effective technique for stabilizing DQN training.
        """
        frac = min(1.0, self.steps_done / float(self.eps_decay_steps))
        return self.eps_start + frac * (self.eps_end - self.eps_start)

    def select_action(self, state_vec):
        eps = self.epsilon_by_step()        # compute exploration rate
        self.steps_done += 1                # increment step count this parameter is used for epsilon decay (see above function)
        # Epsilon-greedy action selection if RNG < eps: random action (explore)
        # This means, we ignore neural network policy and pick random action with probability epsilon
        if np.random.rand() < eps:
            return np.random.randint(self.n_actions)
        # Else: greedy action from policy_net (exploit)
        with torch.no_grad():                   # no grad needed for action selection
            s = torch.from_numpy(np.asarray(state_vec, dtype=np.float32)).unsqueeze(0).to(self.device)  # convert state to tensor and add batch dim
            q = self.policy_net(s)              # get Q-values from policy net
            return int(q.argmax(dim=1).item())  # using q-value to select best action index ideally, action with highest Q-value.

    def store_transition(self, s_vec, a, r, ns_vec, done):
        """
        storing one transition in replay buffer
        1. s_vec: current state vector
        2. a: action taken (index)
        3. r: reward received
        4. ns_vec: next state vector
        5. done: whether episode ended after this transition (bool 0.0 or 1.0)
        6. Calls replay_buffer.push() to store transition with proper scaling/clipping
        """
        self.replay_buffer.push(s_vec, a, r, ns_vec, done)

    def _hard_update_target(self):
        """
        Hard update: copy policy_net weights to target_net
        """
        # recall: policy_net is updated every grad step -- actively training/learning
        #         target_net is updated slowly -- almost frozen
        # Therefore, periodically copy policy_net weights to target_net to keep target_net up-to-date
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def _soft_update_target(self):
        """
        This is a soft (Polyak) update for the target network. 
        It makes the target network slowly track the policy network instead of copying it all at once.
        """
        with torch.no_grad():
            for p, tp in zip(self.policy_net.parameters(), self.target_net.parameters()):
                # p = parameter from policy_net
                # tp = parameter from target_net
                # Update target parameter: tp = (1 - tau) * tp + tau * p
                # This means target_net parameters slowly move towards policy_net parameters
                tp.data.mul_(1.0 - self.tau)        # decay taget parameter
                tp.data.add_(self.tau * p.data)     # add fraction of policy parameter to target parameter


    def train_step(self):
        """
        Training single step for DQN agent using Double DQN update.
        1. Sample batch from replay buffer
        2. Compute current Q-values for taken actions using policy_net
        3. Compute target Q-values using target_net and policy_net (Double DQN): action from policy_net, value from target_net
        4. Compute (TemporalDifference) Huber loss between current Q and target: measures how wrong is my Q-value estimate
        5. Backpropagate loss and update policy_net parameters: adjust policy_net to reduce TD error--carefully.
        6. Update target_net parameters using hard or soft update
        7. Return loss value for logging
        """
        if len(self.replay_buffer) < self.batch_size:
            return None

        # Sample a batch of state_vector from replay buffer
        states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size, device=self.device)

        # Current Q(s,a): that the policy network assigns to the action that was actually taken, for each state in the batch.
        # self.policy_net(states): shape (batch_size, n_actions) -- each row has Q-values for all actions in that state
        # gather(1, actions.unsqueeze(1)): select Q-values for taken actions
        # Note: gather(1, ...) selects values along dim=1 (action dim) for each row in batch
        # squeeze(1): remove extra dim to get shape (batch_size,)
        q_sa = self.policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)

        with torch.no_grad():
            # Double DQN target: action from policy, value from target
            next_actions = self.policy_net(next_states).argmax(dim=1, keepdim=True)
            next_q = self.target_net(next_states).gather(1, next_actions).squeeze(1)    # Q-values for next states from target net from selected actions
            target = rewards + (1.0 - dones) * self.gamma * next_q                      # TD target: r + gamma * max_a Q(s',a) if not done, else r
        # What this does:
        # target = r + gamma * Q_target(s', argmax_a Q_policy(s',a))
        # Reduce maximization bias by using policy net to select action (argmax)

        # Huber loss between current Q and target
        # \delta = q_sa - target
        # L(\delta) = 0.5 * \delta^2 if |\delta| < 1 
        #           = |\delta| - 0.5 if |\delta| >= 1
        # Prefer this over MSE loss as it is less sensitive to outliers and large TD errors
        loss = F.smooth_l1_loss(q_sa, target)

        # Learning steps:
        # 1. Zero gradients: clear old gradients from previous step
        # 2. Backpropagate loss: compute gradients of loss w.r.t. network parameters
        # 3. Gradient clipping: clip gradients to max norm to avoid explosion
        # 4. Optimizer step: update network parameters using computed gradients
        self.optimizer.zero_grad(set_to_none=True)
        loss.backward()                                 # compute gradients dL/dtheta for policy_net parameters
                                                        # gradient flow: loss -> q_sa -> policy_net parameters
                                                        # do NOT flow through target_net (detached), next stage computation
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 10.0)  # clip gradients to max norm of 10.0 for stability: g = g * min(1, 10.0/||g||)
        self.optimizer.step()                           # update policy_net parameters using optimizer (Adam): theta = theta - lr * dL/dtheta

        self.grad_steps += 1

        # Target updates:
        # recall: self.tau is Polyak factor for soft update
        if self.tau is not None:
            self._soft_update_target()  # Polyak soft update: theta_target = (1 - tau) * theta_target + tau * theta_policy
        else:
            if self.grad_steps % self.target_update_steps == 0: # hard-update schedule (once every self.target_update_steps)
                # we dont do this every step, only every N grad steps since target net is supposed to be "slow-moving"
                self._hard_update_target()                      # hard update: copy policy_net parameters to target_net

        return float(loss.item())


# -------------------------
# 5) Training loop
# -------------------------

def train_dqn(
    agent,
    episode_table,
    demand_model,
    n_episodes=50_000,
    horizon=20,
    log_interval=100,
    seed=42,
    start_training_after=5_000,
    train_every=1
):
    rng = np.random.default_rng(seed)

    episode_rewards = []
    episode_losses = []
    total_env_steps = 0

    print("=" * 90)
    print("TRAINING DQN AGENT (STABLE SETUP)")
    print("=" * 90)
    print(f"Episodes: {n_episodes} | Horizon: {horizon}")
    print(f"Batch size: {agent.batch_size} | Gamma: {agent.gamma}")
    print(f"LR: {agent.optimizer.param_groups[0]['lr']}")
    print(f"Reward scale: {agent.replay_buffer.reward_scale} | Reward clip: {agent.replay_buffer.reward_clip}")
    print(f"Eps: start={agent.eps_start}, end={agent.eps_end}, decay_steps={agent.eps_decay_steps}")
    print(f"Start training after buffer >= {start_training_after}")
    print("")

    for ep in range(1, n_episodes + 1):
        # random start
        idx = int(rng.integers(0, len(episode_table)))
        s_dict = episode_table.iloc[idx].to_dict()
        s_vec = state_to_vec(s_dict)

        ep_reward = 0.0
        ep_loss_vals = []

        for t in range(horizon):
            a_idx = agent.select_action(s_vec)
            a_mult = agent.actions_array[a_idx]

            # env_step must return: (bin or whatever, reward, next_state_dict)
            _, reward, ns_dict = env_step(demand_model, s_dict, a_mult)

            done = (t == horizon - 1)
            ns_vec = state_to_vec(ns_dict)

            agent.store_transition(s_vec, a_idx, reward, ns_vec, done)

            total_env_steps += 1

            if len(agent.replay_buffer) >= start_training_after and (total_env_steps % train_every == 0):
                loss = agent.train_step()
                if loss is not None:
                    ep_loss_vals.append(loss)

            s_dict, s_vec = ns_dict, ns_vec
            ep_reward += reward

        episode_rewards.append(ep_reward)
        episode_losses.append(float(np.mean(ep_loss_vals)) if ep_loss_vals else np.nan)

        if ep % log_interval == 0:
            recent_rewards = episode_rewards[-log_interval:]
            recent_losses = [x for x in episode_losses[-log_interval:] if not np.isnan(x)]

            avg_reward = float(np.mean(recent_rewards))
            avg_loss = float(np.mean(recent_losses)) if recent_losses else float("nan")
            eps_now = agent.epsilon_by_step()

            print(
                f"Episode {ep:5d}/{n_episodes} | "
                f"Avg Reward: {avg_reward:9.2f} | "
                f"Avg Loss: {avg_loss:9.4f} | "
                f"Eps: {eps_now:6.4f} | "
                f"Buffer: {len(agent.replay_buffer):7d} | "
                f"EnvSteps: {total_env_steps:9d} | "
                f"GradSteps: {agent.grad_steps:9d}"
            )

    metrics = {
        "episode_rewards": episode_rewards,
        "episode_losses": episode_losses,
        "buffer_size": len(agent.replay_buffer),
        "total_env_steps": total_env_steps,
        "grad_steps": agent.grad_steps
    }
    return agent, metrics

# %%
# =========================
# 6) Example usage
# =========================

# ACTION_MULTS must exist (e.g., np.array([...]) or list)
# ACTION_MULTS = np.array([0.9, 0.95, 1.0, 1.05, 1.1], dtype=np.float32)

device = device  # use your existing device
actions_array = np.array(ACTION_MULTS, dtype=np.float32)
n_actions = len(actions_array)

agent = DQNAgent(
    state_dim=STATE_DIM,
    n_actions=n_actions,
    actions_array=actions_array,
    hidden_dims=(128, 128),
    lr=1e-4,
    gamma=0.97,
    eps_start=1.0,
    eps_end=0.05,
    eps_decay_steps=80_000,      # tune: 80k-200k
    batch_size=128,
    buffer_capacity=200_000,
    target_update_steps=None,   # tune: 2k-10k
    tau=0.005,                    # or tau=0.005 for soft updates
    use_dueling=True,
    reward_scale=1/1000,         # IMPORTANT: tune based on reward magnitude
    reward_clip=None,            # or 10.0
    device=device
)

agent, metrics = train_dqn(
    agent=agent,
    episode_table=episode_table,
    demand_model=demand_model,
    n_episodes=20_000,
    horizon=20,
    log_interval=100,
    seed=42,
    start_training_after=5_000,
    train_every=1
)

print("\nFinal Training Statistics:")
print(f"  Buffer size: {len(agent.replay_buffer):,}")
print(f"  Final epsilon (step-based): {agent.epsilon_by_step():.4f}")
print(f"  Avg reward (last 100 eps): {np.mean(metrics['episode_rewards'][-100:]):.2f}")
last_losses = [x for x in metrics["episode_losses"][-100:] if not np.isnan(x)]
if last_losses:
    print(f"  Avg loss (last 100 eps): {np.mean(last_losses):.4f}")
# Out:
# ==========================================================================================
# TRAINING DQN AGENT (STABLE SETUP)
# ==========================================================================================
# Episodes: 20000 | Horizon: 20
# Batch size: 128 | Gamma: 0.97
# LR: 0.0001
# Reward scale: 0.001 | Reward clip: None
# Eps: start=1.0, end=0.05, decay_steps=80000
# Start training after buffer >= 5000
#
# Episode   100/20000 | Avg Reward:   1476.39 | Avg Loss:       nan | Eps: 0.9762 | Buffer:    2000 | EnvSteps:      2000 | GradSteps:         0
# Episode   200/20000 | Avg Reward:   1476.56 | Avg Loss:       nan | Eps: 0.9525 | Buffer:    4000 | EnvSteps:      4000 | GradSteps:         0
# Episode   300/20000 | Avg Reward:   1643.21 | Avg Loss:    0.0051 | Eps: 0.9287 | Buffer:    6000 | EnvSteps:      6000 | GradSteps:      1001
# Episode   400/20000 | Avg Reward:   2378.11 | Avg Loss:    0.0223 | Eps: 0.9050 | Buffer:    8000 | EnvSteps:      8000 | GradSteps:      3001
# Episode   500/20000 | Avg Reward:   1135.07 | Avg Loss:    0.0492 | Eps: 0.8812 | Buffer:   10000 | EnvSteps:     10000 | GradSteps:      5001
# Episode   600/20000 | Avg Reward:   1107.28 | Avg Loss:    0.0723 | Eps: 0.8575 | Buffer:   12000 | EnvSteps:     12000 | GradSteps:      7001
# Episode   700/20000 | Avg Reward:   1229.89 | Avg Loss:    0.0879 | Eps: 0.8337 | Buffer:   14000 | EnvSteps:     14000 | GradSteps:      9001
# Episode   800/20000 | Avg Reward:   3550.12 | Avg Loss:    0.1121 | Eps: 0.8100 | Buffer:   16000 | EnvSteps:     16000 | GradSteps:     11001
# Episode   900/20000 | Avg Reward:   1553.62 | Avg Loss:    0.1341 | Eps: 0.7863 | Buffer:   18000 | EnvSteps:     18000 | GradSteps:     13001
# Episode  1000/20000 | Avg Reward:   1196.58 | Avg Loss:    0.1501 | Eps: 0.7625 | Buffer:   20000 | EnvSteps:     20000 | GradSteps:     15001
# Episode  1100/20000 | Avg Reward:   1454.03 | Avg Loss:    0.1565 | Eps: 0.7388 | Buffer:   22000 | EnvSteps:     22000 | GradSteps:     17001
# Episode  1200/20000 | Avg Reward:   1205.87 | Avg Loss:    0.1765 | Eps: 0.7150 | Buffer:   24000 | EnvSteps:     24000 | GradSteps:     19001
# Episode  1300/20000 | Avg Reward:   1490.33 | Avg Loss:    0.1763 | Eps: 0.6913 | Buffer:   26000 | EnvSteps:     26000 | GradSteps:     21001
# Episode  1400/20000 | Avg Reward:   1254.63 | Avg Loss:    0.1692 | Eps: 0.6675 | Buffer:   28000 | EnvSteps:     28000 | GradSteps:     23001
# Episode  1500/20000 | Avg Reward:   1411.59 | Avg Loss:    0.1820 | Eps: 0.6438 | Buffer:   30000 | EnvSteps:     30000 | GradSteps:     25001
# Episode  1600/20000 | Avg Reward:   3366.75 | Avg Loss:    0.1966 | Eps: 0.6200 | Buffer:   32000 | EnvSteps:     32000 | GradSteps:     27001
# Episode  1700/20000 | Avg Reward:   1762.80 | Avg Loss:    0.1995 | Eps: 0.5962 | Buffer:   34000 | EnvSteps:     34000 | GradSteps:     29001
# Episode  1800/20000 | Avg Reward:   1482.87 | Avg Loss:    0.2214 | Eps: 0.5725 | Buffer:   36000 | EnvSteps:     36000 | GradSteps:     31001
# Episode  1900/20000 | Avg Reward:   1172.25 | Avg Loss:    0.2241 | Eps: 0.5488 | Buffer:   38000 | EnvSteps:     38000 | GradSteps:     33001
# Episode  2000/20000 | Avg Reward:   3306.60 | Avg Loss:    0.2239 | Eps: 0.5250 | Buffer:   40000 | EnvSteps:     40000 | GradSteps:     35001
# Episode  2100/20000 | Avg Reward:  16299.94 | Avg Loss:    0.2402 | Eps: 0.5012 | Buffer:   42000 | EnvSteps:     42000 | GradSteps:     37001
# Episode  2200/20000 | Avg Reward:   1643.70 | Avg Loss:    0.2805 | Eps: 0.4775 | Buffer:   44000 | EnvSteps:     44000 | GradSteps:     39001
# Episode  2300/20000 | Avg Reward:   1897.27 | Avg Loss:    0.2862 | Eps: 0.4538 | Buffer:   46000 | EnvSteps:     46000 | GradSteps:     41001
# Episode  2400/20000 | Avg Reward:   1486.10 | Avg Loss:    0.2960 | Eps: 0.4300 | Buffer:   48000 | EnvSteps:     48000 | GradSteps:     43001
# Episode  2500/20000 | Avg Reward:   1479.48 | Avg Loss:    0.3235 | Eps: 0.4062 | Buffer:   50000 | EnvSteps:     50000 | GradSteps:     45001
# Episode  2600/20000 | Avg Reward:   2346.38 | Avg Loss:    0.3217 | Eps: 0.3825 | Buffer:   52000 | EnvSteps:     52000 | GradSteps:     47001
# Episode  2700/20000 | Avg Reward:   2175.39 | Avg Loss:    0.3809 | Eps: 0.3588 | Buffer:   54000 | EnvSteps:     54000 | GradSteps:     49001
# Episode  2800/20000 | Avg Reward:   2158.30 | Avg Loss:    0.3831 | Eps: 0.3350 | Buffer:   56000 | EnvSteps:     56000 | GradSteps:     51001
# Episode  2900/20000 | Avg Reward:  11558.35 | Avg Loss:    0.4719 | Eps: 0.3113 | Buffer:   58000 | EnvSteps:     58000 | GradSteps:     53001
# Episode  3000/20000 | Avg Reward:   2085.84 | Avg Loss:    0.5009 | Eps: 0.2875 | Buffer:   60000 | EnvSteps:     60000 | GradSteps:     55001
# Episode  3100/20000 | Avg Reward:   1677.11 | Avg Loss:    0.5295 | Eps: 0.2638 | Buffer:   62000 | EnvSteps:     62000 | GradSteps:     57001
# Episode  3200/20000 | Avg Reward:  10376.14 | Avg Loss:    0.5630 | Eps: 0.2400 | Buffer:   64000 | EnvSteps:     64000 | GradSteps:     59001
# Episode  3300/20000 | Avg Reward:   1716.25 | Avg Loss:    0.5941 | Eps: 0.2163 | Buffer:   66000 | EnvSteps:     66000 | GradSteps:     61001
# Episode  3400/20000 | Avg Reward:   2007.56 | Avg Loss:    0.5456 | Eps: 0.1925 | Buffer:   68000 | EnvSteps:     68000 | GradSteps:     63001
# Episode  3500/20000 | Avg Reward:   1614.21 | Avg Loss:    0.4800 | Eps: 0.1688 | Buffer:   70000 | EnvSteps:     70000 | GradSteps:     65001
# Episode  3600/20000 | Avg Reward:   1595.79 | Avg Loss:    0.4826 | Eps: 0.1450 | Buffer:   72000 | EnvSteps:     72000 | GradSteps:     67001
# Episode  3700/20000 | Avg Reward:   1907.95 | Avg Loss:    0.4684 | Eps: 0.1212 | Buffer:   74000 | EnvSteps:     74000 | GradSteps:     69001
# Episode  3800/20000 | Avg Reward:   2241.45 | Avg Loss:    0.4359 | Eps: 0.0975 | Buffer:   76000 | EnvSteps:     76000 | GradSteps:     71001
# Episode  3900/20000 | Avg Reward:   1400.89 | Avg Loss:    0.3939 | Eps: 0.0738 | Buffer:   78000 | EnvSteps:     78000 | GradSteps:     73001
# Episode  4000/20000 | Avg Reward:  10930.90 | Avg Loss:    0.4305 | Eps: 0.0500 | Buffer:   80000 | EnvSteps:     80000 | GradSteps:     75001
# Episode  4100/20000 | Avg Reward:   1592.64 | Avg Loss:    0.3864 | Eps: 0.0500 | Buffer:   82000 | EnvSteps:     82000 | GradSteps:     77001
# Episode  4200/20000 | Avg Reward:   2371.36 | Avg Loss:    0.3853 | Eps: 0.0500 | Buffer:   84000 | EnvSteps:     84000 | GradSteps:     79001
# Episode  4300/20000 | Avg Reward:   1734.83 | Avg Loss:    0.3807 | Eps: 0.0500 | Buffer:   86000 | EnvSteps:     86000 | GradSteps:     81001
# Episode  4400/20000 | Avg Reward:   2060.27 | Avg Loss:    0.3732 | Eps: 0.0500 | Buffer:   88000 | EnvSteps:     88000 | GradSteps:     83001
# Episode  4500/20000 | Avg Reward:   1521.65 | Avg Loss:    0.3379 | Eps: 0.0500 | Buffer:   90000 | EnvSteps:     90000 | GradSteps:     85001
# Episode  4600/20000 | Avg Reward:   1163.96 | Avg Loss:    0.3283 | Eps: 0.0500 | Buffer:   92000 | EnvSteps:     92000 | GradSteps:     87001
# Episode  4700/20000 | Avg Reward:   1272.83 | Avg Loss:    0.3148 | Eps: 0.0500 | Buffer:   94000 | EnvSteps:     94000 | GradSteps:     89001
# Episode  4800/20000 | Avg Reward:   1725.56 | Avg Loss:    0.3037 | Eps: 0.0500 | Buffer:   96000 | EnvSteps:     96000 | GradSteps:     91001
# Episode  4900/20000 | Avg Reward:  10932.90 | Avg Loss:    0.3063 | Eps: 0.0500 | Buffer:   98000 | EnvSteps:     98000 | GradSteps:     93001
# Episode  5000/20000 | Avg Reward:   2402.79 | Avg Loss:    0.3390 | Eps: 0.0500 | Buffer:  100000 | EnvSteps:    100000 | GradSteps:     95001
# Episode  5100/20000 | Avg Reward:   2671.60 | Avg Loss:    0.2976 | Eps: 0.0500 | Buffer:  102000 | EnvSteps:    102000 | GradSteps:     97001
# Episode  5200/20000 | Avg Reward:  10919.44 | Avg Loss:    0.3299 | Eps: 0.0500 | Buffer:  104000 | EnvSteps:    104000 | GradSteps:     99001
# Episode  5300/20000 | Avg Reward:   2771.32 | Avg Loss:    0.3530 | Eps: 0.0500 | Buffer:  106000 | EnvSteps:    106000 | GradSteps:    101001
# Episode  5400/20000 | Avg Reward:   2721.45 | Avg Loss:    0.3152 | Eps: 0.0500 | Buffer:  108000 | EnvSteps:    108000 | GradSteps:    103001
# Episode  5500/20000 | Avg Reward:   2106.07 | Avg Loss:    0.3345 | Eps: 0.0500 | Buffer:  110000 | EnvSteps:    110000 | GradSteps:    105001
# Episode  5600/20000 | Avg Reward:   4173.81 | Avg Loss:    0.3443 | Eps: 0.0500 | Buffer:  112000 | EnvSteps:    112000 | GradSteps:    107001
# Episode  5700/20000 | Avg Reward:   2233.83 | Avg Loss:    0.3711 | Eps: 0.0500 | Buffer:  114000 | EnvSteps:    114000 | GradSteps:    109001
# Episode  5800/20000 | Avg Reward:  10029.28 | Avg Loss:    0.3305 | Eps: 0.0500 | Buffer:  116000 | EnvSteps:    116000 | GradSteps:    111001
# Episode  5900/20000 | Avg Reward:   2356.53 | Avg Loss:    0.3274 | Eps: 0.0500 | Buffer:  118000 | EnvSteps:    118000 | GradSteps:    113001
# Episode  6000/20000 | Avg Reward:   2278.46 | Avg Loss:    0.3358 | Eps: 0.0500 | Buffer:  120000 | EnvSteps:    120000 | GradSteps:    115001
# Episode  6100/20000 | Avg Reward:   2508.86 | Avg Loss:    0.3796 | Eps: 0.0500 | Buffer:  122000 | EnvSteps:    122000 | GradSteps:    117001
# Episode  6200/20000 | Avg Reward:   6880.99 | Avg Loss:    0.3271 | Eps: 0.0500 | Buffer:  124000 | EnvSteps:    124000 | GradSteps:    119001
# Episode  6300/20000 | Avg Reward:  97408.39 | Avg Loss:    0.3614 | Eps: 0.0500 | Buffer:  126000 | EnvSteps:    126000 | GradSteps:    121001
# Episode  6400/20000 | Avg Reward:   2551.93 | Avg Loss:    0.4216 | Eps: 0.0500 | Buffer:  128000 | EnvSteps:    128000 | GradSteps:    123001
# Episode  6500/20000 | Avg Reward:   2127.91 | Avg Loss:    0.3709 | Eps: 0.0500 | Buffer:  130000 | EnvSteps:    130000 | GradSteps:    125001
# Episode  6600/20000 | Avg Reward:   2090.58 | Avg Loss:    0.4211 | Eps: 0.0500 | Buffer:  132000 | EnvSteps:    132000 | GradSteps:    127001
# Episode  6700/20000 | Avg Reward:   3987.98 | Avg Loss:    0.3866 | Eps: 0.0500 | Buffer:  134000 | EnvSteps:    134000 | GradSteps:    129001
# Episode  6800/20000 | Avg Reward:   1480.99 | Avg Loss:    0.3945 | Eps: 0.0500 | Buffer:  136000 | EnvSteps:    136000 | GradSteps:    131001
# Episode  6900/20000 | Avg Reward:   3772.81 | Avg Loss:    0.4192 | Eps: 0.0500 | Buffer:  138000 | EnvSteps:    138000 | GradSteps:    133001
# Episode  7000/20000 | Avg Reward:   2133.85 | Avg Loss:    0.3949 | Eps: 0.0500 | Buffer:  140000 | EnvSteps:    140000 | GradSteps:    135001
# Episode  7100/20000 | Avg Reward:   2466.21 | Avg Loss:    0.4336 | Eps: 0.0500 | Buffer:  142000 | EnvSteps:    142000 | GradSteps:    137001
# Episode  7200/20000 | Avg Reward:   6694.46 | Avg Loss:    0.4286 | Eps: 0.0500 | Buffer:  144000 | EnvSteps:    144000 | GradSteps:    139001
# Episode  7300/20000 | Avg Reward:   2379.77 | Avg Loss:    0.4115 | Eps: 0.0500 | Buffer:  146000 | EnvSteps:    146000 | GradSteps:    141001
# Episode  7400/20000 | Avg Reward:  13513.84 | Avg Loss:    0.4594 | Eps: 0.0500 | Buffer:  148000 | EnvSteps:    148000 | GradSteps:    143001
# Episode  7500/20000 | Avg Reward:   2135.71 | Avg Loss:    0.4119 | Eps: 0.0500 | Buffer:  150000 | EnvSteps:    150000 | GradSteps:    145001
# Episode  7600/20000 | Avg Reward:   4073.80 | Avg Loss:    0.4897 | Eps: 0.0500 | Buffer:  152000 | EnvSteps:    152000 | GradSteps:    147001
# Episode  7700/20000 | Avg Reward:   5350.89 | Avg Loss:    0.5047 | Eps: 0.0500 | Buffer:  154000 | EnvSteps:    154000 | GradSteps:    149001
# Episode  7800/20000 | Avg Reward:   2429.08 | Avg Loss:    0.5350 | Eps: 0.0500 | Buffer:  156000 | EnvSteps:    156000 | GradSteps:    151001
# Episode  7900/20000 | Avg Reward:   2804.55 | Avg Loss:    0.5076 | Eps: 0.0500 | Buffer:  158000 | EnvSteps:    158000 | GradSteps:    153001
# Episode  8000/20000 | Avg Reward:   2518.27 | Avg Loss:    0.4789 | Eps: 0.0500 | Buffer:  160000 | EnvSteps:    160000 | GradSteps:    155001
# Episode  8100/20000 | Avg Reward:  13520.39 | Avg Loss:    0.5240 | Eps: 0.0500 | Buffer:  162000 | EnvSteps:    162000 | GradSteps:    157001
# Episode  8200/20000 | Avg Reward:   2613.22 | Avg Loss:    0.5367 | Eps: 0.0500 | Buffer:  164000 | EnvSteps:    164000 | GradSteps:    159001
# Episode  8300/20000 | Avg Reward:   2532.07 | Avg Loss:    0.5352 | Eps: 0.0500 | Buffer:  166000 | EnvSteps:    166000 | GradSteps:    161001
# Episode  8400/20000 | Avg Reward:   1416.08 | Avg Loss:    0.5895 | Eps: 0.0500 | Buffer:  168000 | EnvSteps:    168000 | GradSteps:    163001
# Episode  8500/20000 | Avg Reward:   3750.53 | Avg Loss:    0.5650 | Eps: 0.0500 | Buffer:  170000 | EnvSteps:    170000 | GradSteps:    165001
# Episode  8600/20000 | Avg Reward:   2461.83 | Avg Loss:    0.5397 | Eps: 0.0500 | Buffer:  172000 | EnvSteps:    172000 | GradSteps:    167001
# Episode  8700/20000 | Avg Reward:   2722.86 | Avg Loss:    0.5217 | Eps: 0.0500 | Buffer:  174000 | EnvSteps:    174000 | GradSteps:    169001
# Episode  8800/20000 | Avg Reward:   1670.12 | Avg Loss:    0.5276 | Eps: 0.0500 | Buffer:  176000 | EnvSteps:    176000 | GradSteps:    171001
# Episode  8900/20000 | Avg Reward:   1350.69 | Avg Loss:    0.5499 | Eps: 0.0500 | Buffer:  178000 | EnvSteps:    178000 | GradSteps:    173001
# Episode  9000/20000 | Avg Reward:   1394.62 | Avg Loss:    0.5732 | Eps: 0.0500 | Buffer:  180000 | EnvSteps:    180000 | GradSteps:    175001
# Episode  9100/20000 | Avg Reward:   2577.44 | Avg Loss:    0.5243 | Eps: 0.0500 | Buffer:  182000 | EnvSteps:    182000 | GradSteps:    177001
# Episode  9200/20000 | Avg Reward:   1512.28 | Avg Loss:    0.4956 | Eps: 0.0500 | Buffer:  184000 | EnvSteps:    184000 | GradSteps:    179001
# Episode  9300/20000 | Avg Reward:   1997.15 | Avg Loss:    0.5036 | Eps: 0.0500 | Buffer:  186000 | EnvSteps:    186000 | GradSteps:    181001
# Episode  9400/20000 | Avg Reward:   1880.71 | Avg Loss:    0.5508 | Eps: 0.0500 | Buffer:  188000 | EnvSteps:    188000 | GradSteps:    183001
# Episode  9500/20000 | Avg Reward:   2764.28 | Avg Loss:    0.4918 | Eps: 0.0500 | Buffer:  190000 | EnvSteps:    190000 | GradSteps:    185001
# Episode  9600/20000 | Avg Reward:   2370.82 | Avg Loss:    0.4916 | Eps: 0.0500 | Buffer:  192000 | EnvSteps:    192000 | GradSteps:    187001
# Episode  9700/20000 | Avg Reward:   3385.63 | Avg Loss:    0.5329 | Eps: 0.0500 | Buffer:  194000 | EnvSteps:    194000 | GradSteps:    189001
# Episode  9800/20000 | Avg Reward:   2440.16 | Avg Loss:    0.5424 | Eps: 0.0500 | Buffer:  196000 | EnvSteps:    196000 | GradSteps:    191001
# Episode  9900/20000 | Avg Reward:   1814.92 | Avg Loss:    0.4615 | Eps: 0.0500 | Buffer:  198000 | EnvSteps:    198000 | GradSteps:    193001
# Episode 10000/20000 | Avg Reward:   9889.26 | Avg Loss:    0.5079 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    200000 | GradSteps:    195001
# Episode 10100/20000 | Avg Reward:   1876.66 | Avg Loss:    0.6136 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    202000 | GradSteps:    197001
# Episode 10200/20000 | Avg Reward:   2158.31 | Avg Loss:    0.4727 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    204000 | GradSteps:    199001
# Episode 10300/20000 | Avg Reward:   3989.34 | Avg Loss:    0.5297 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    206000 | GradSteps:    201001
# Episode 10400/20000 | Avg Reward:   4360.15 | Avg Loss:    0.4598 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    208000 | GradSteps:    203001
# Episode 10500/20000 | Avg Reward:   2597.59 | Avg Loss:    0.5746 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    210000 | GradSteps:    205001
# Episode 10600/20000 | Avg Reward:   2626.43 | Avg Loss:    0.5381 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    212000 | GradSteps:    207001
# Episode 10700/20000 | Avg Reward:   2719.19 | Avg Loss:    0.4900 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    214000 | GradSteps:    209001
# Episode 10800/20000 | Avg Reward:   4465.19 | Avg Loss:    0.4660 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    216000 | GradSteps:    211001
# Episode 10900/20000 | Avg Reward:   1873.54 | Avg Loss:    0.4943 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    218000 | GradSteps:    213001
# Episode 11000/20000 | Avg Reward:   7308.79 | Avg Loss:    0.4914 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    220000 | GradSteps:    215001
# Episode 11100/20000 | Avg Reward:   3089.83 | Avg Loss:    0.4435 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    222000 | GradSteps:    217001
# Episode 11200/20000 | Avg Reward:   2695.94 | Avg Loss:    0.5259 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    224000 | GradSteps:    219001
# Episode 11300/20000 | Avg Reward:   2102.43 | Avg Loss:    0.3940 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    226000 | GradSteps:    221001
# Episode 11400/20000 | Avg Reward:   1754.72 | Avg Loss:    0.4579 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    228000 | GradSteps:    223001
# Episode 11500/20000 | Avg Reward:   1564.14 | Avg Loss:    0.5817 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    230000 | GradSteps:    225001
# Episode 11600/20000 | Avg Reward:   3775.71 | Avg Loss:    0.4650 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    232000 | GradSteps:    227001
# Episode 11700/20000 | Avg Reward:   3982.89 | Avg Loss:    0.5033 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    234000 | GradSteps:    229001
# Episode 11800/20000 | Avg Reward:   2493.57 | Avg Loss:    0.4078 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    236000 | GradSteps:    231001
# Episode 11900/20000 | Avg Reward:   2066.61 | Avg Loss:    0.4186 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    238000 | GradSteps:    233001
# Episode 12000/20000 | Avg Reward:   2252.62 | Avg Loss:    0.4142 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    240000 | GradSteps:    235001
# Episode 12100/20000 | Avg Reward:   2976.84 | Avg Loss:    0.5757 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    242000 | GradSteps:    237001
# Episode 12200/20000 | Avg Reward:   1815.65 | Avg Loss:    0.4217 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    244000 | GradSteps:    239001
# Episode 12300/20000 | Avg Reward:   3499.70 | Avg Loss:    0.5419 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    246000 | GradSteps:    241001
# Episode 12400/20000 | Avg Reward:   2967.46 | Avg Loss:    0.3977 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    248000 | GradSteps:    243001
# Episode 12500/20000 | Avg Reward:   6816.76 | Avg Loss:    0.4993 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    250000 | GradSteps:    245001
# Episode 12600/20000 | Avg Reward:  10484.64 | Avg Loss:    0.4394 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    252000 | GradSteps:    247001
# Episode 12700/20000 | Avg Reward:   3320.07 | Avg Loss:    0.5117 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    254000 | GradSteps:    249001
# Episode 12800/20000 | Avg Reward:   4051.01 | Avg Loss:    0.5575 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    256000 | GradSteps:    251001
# Episode 12900/20000 | Avg Reward:   2256.42 | Avg Loss:    0.5382 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    258000 | GradSteps:    253001
# Episode 13000/20000 | Avg Reward:   3916.50 | Avg Loss:    0.5269 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    260000 | GradSteps:    255001
# Episode 13100/20000 | Avg Reward:   4793.80 | Avg Loss:    0.4620 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    262000 | GradSteps:    257001
# Episode 13200/20000 | Avg Reward:   2172.24 | Avg Loss:    0.5123 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    264000 | GradSteps:    259001
# Episode 13300/20000 | Avg Reward:   3408.32 | Avg Loss:    0.5538 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    266000 | GradSteps:    261001
# Episode 13400/20000 | Avg Reward:   2429.78 | Avg Loss:    0.5136 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    268000 | GradSteps:    263001
# Episode 13500/20000 | Avg Reward:   2090.96 | Avg Loss:    0.5158 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    270000 | GradSteps:    265001
# Episode 13600/20000 | Avg Reward:   5042.30 | Avg Loss:    0.4293 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    272000 | GradSteps:    267001
# Episode 13700/20000 | Avg Reward:   2779.72 | Avg Loss:    0.5116 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    274000 | GradSteps:    269001
# Episode 13800/20000 | Avg Reward:   3610.92 | Avg Loss:    0.5468 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    276000 | GradSteps:    271001
# Episode 13900/20000 | Avg Reward:  10429.40 | Avg Loss:    0.6574 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    278000 | GradSteps:    273001
# Episode 14000/20000 | Avg Reward:   2388.60 | Avg Loss:    0.5704 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    280000 | GradSteps:    275001
# Episode 14100/20000 | Avg Reward:   6135.12 | Avg Loss:    0.5396 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    282000 | GradSteps:    277001
# Episode 14200/20000 | Avg Reward:   2147.99 | Avg Loss:    0.5924 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    284000 | GradSteps:    279001
# Episode 14300/20000 | Avg Reward:  10129.19 | Avg Loss:    0.7477 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    286000 | GradSteps:    281001
# Episode 14400/20000 | Avg Reward:  10396.80 | Avg Loss:    0.6290 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    288000 | GradSteps:    283001
# Episode 14500/20000 | Avg Reward:   4018.94 | Avg Loss:    0.7031 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    290000 | GradSteps:    285001
# Episode 14600/20000 | Avg Reward:   2878.37 | Avg Loss:    0.7647 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    292000 | GradSteps:    287001
# Episode 14700/20000 | Avg Reward:   3105.77 | Avg Loss:    0.6735 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    294000 | GradSteps:    289001
# Episode 14800/20000 | Avg Reward:   2423.60 | Avg Loss:    0.6091 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    296000 | GradSteps:    291001
# Episode 14900/20000 | Avg Reward:   2194.25 | Avg Loss:    0.6997 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    298000 | GradSteps:    293001
# Episode 15000/20000 | Avg Reward:   3877.90 | Avg Loss:    0.6111 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    300000 | GradSteps:    295001
# Episode 15100/20000 | Avg Reward:   3933.77 | Avg Loss:    0.6112 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    302000 | GradSteps:    297001
# Episode 15200/20000 | Avg Reward:   9197.44 | Avg Loss:    0.5744 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    304000 | GradSteps:    299001
# Episode 15300/20000 | Avg Reward:   2038.75 | Avg Loss:    0.7153 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    306000 | GradSteps:    301001
# Episode 15400/20000 | Avg Reward:   7512.44 | Avg Loss:    0.7213 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    308000 | GradSteps:    303001
# Episode 15500/20000 | Avg Reward:   3344.27 | Avg Loss:    0.6660 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    310000 | GradSteps:    305001
# Episode 15600/20000 | Avg Reward:  67460.83 | Avg Loss:    0.7169 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    312000 | GradSteps:    307001
# Episode 15700/20000 | Avg Reward:   3084.34 | Avg Loss:    0.7246 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    314000 | GradSteps:    309001
# Episode 15800/20000 | Avg Reward:   3918.71 | Avg Loss:    0.7227 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    316000 | GradSteps:    311001
# Episode 15900/20000 | Avg Reward:   3407.31 | Avg Loss:    0.6632 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    318000 | GradSteps:    313001
# Episode 16000/20000 | Avg Reward:   2884.71 | Avg Loss:    0.7240 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    320000 | GradSteps:    315001
# Episode 16100/20000 | Avg Reward:   1981.91 | Avg Loss:    0.6318 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    322000 | GradSteps:    317001
# Episode 16200/20000 | Avg Reward:   2583.30 | Avg Loss:    0.7591 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    324000 | GradSteps:    319001
# Episode 16300/20000 | Avg Reward:   3422.13 | Avg Loss:    0.6742 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    326000 | GradSteps:    321001
# Episode 16400/20000 | Avg Reward:   3259.18 | Avg Loss:    0.5440 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    328000 | GradSteps:    323001
# Episode 16500/20000 | Avg Reward:   3601.84 | Avg Loss:    0.5462 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    330000 | GradSteps:    325001
# Episode 16600/20000 | Avg Reward:   7097.83 | Avg Loss:    0.5385 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    332000 | GradSteps:    327001
# Episode 16700/20000 | Avg Reward:   4630.43 | Avg Loss:    0.5416 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    334000 | GradSteps:    329001
# Episode 16800/20000 | Avg Reward:   4805.53 | Avg Loss:    0.5212 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    336000 | GradSteps:    331001
# Episode 16900/20000 | Avg Reward:   1926.39 | Avg Loss:    0.5608 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    338000 | GradSteps:    333001
# Episode 17000/20000 | Avg Reward:   6836.69 | Avg Loss:    0.6706 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    340000 | GradSteps:    335001
# Episode 17100/20000 | Avg Reward:   8067.83 | Avg Loss:    0.6206 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    342000 | GradSteps:    337001
# Episode 17200/20000 | Avg Reward:  12376.98 | Avg Loss:    0.6229 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    344000 | GradSteps:    339001
# Episode 17300/20000 | Avg Reward:   2557.11 | Avg Loss:    0.6561 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    346000 | GradSteps:    341001
# Episode 17400/20000 | Avg Reward:   2270.21 | Avg Loss:    0.6281 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    348000 | GradSteps:    343001
# Episode 17500/20000 | Avg Reward:   8281.27 | Avg Loss:    0.7452 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    350000 | GradSteps:    345001
# Episode 17600/20000 | Avg Reward:   2993.16 | Avg Loss:    0.7543 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    352000 | GradSteps:    347001
# Episode 17700/20000 | Avg Reward:   1990.95 | Avg Loss:    0.7759 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    354000 | GradSteps:    349001
# Episode 17800/20000 | Avg Reward:   3543.99 | Avg Loss:    0.8652 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    356000 | GradSteps:    351001
# Episode 17900/20000 | Avg Reward:   2001.62 | Avg Loss:    0.8068 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    358000 | GradSteps:    353001
# Episode 18000/20000 | Avg Reward:   6793.73 | Avg Loss:    0.8889 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    360000 | GradSteps:    355001
# Episode 18100/20000 | Avg Reward:   2749.91 | Avg Loss:    1.0386 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    362000 | GradSteps:    357001
# Episode 18200/20000 | Avg Reward:   2583.34 | Avg Loss:    0.8355 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    364000 | GradSteps:    359001
# Episode 18300/20000 | Avg Reward:   5250.68 | Avg Loss:    0.8682 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    366000 | GradSteps:    361001
# Episode 18400/20000 | Avg Reward:   2670.28 | Avg Loss:    0.9539 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    368000 | GradSteps:    363001
# Episode 18500/20000 | Avg Reward:   5527.29 | Avg Loss:    0.8500 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    370000 | GradSteps:    365001
# Episode 18600/20000 | Avg Reward:   1905.86 | Avg Loss:    0.8016 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    372000 | GradSteps:    367001
# Episode 18700/20000 | Avg Reward:   3481.58 | Avg Loss:    0.8743 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    374000 | GradSteps:    369001
# Episode 18800/20000 | Avg Reward:   2550.01 | Avg Loss:    0.8754 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    376000 | GradSteps:    371001
# Episode 18900/20000 | Avg Reward:   5899.05 | Avg Loss:    0.7428 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    378000 | GradSteps:    373001
# Episode 19000/20000 | Avg Reward:   4127.02 | Avg Loss:    0.6699 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    380000 | GradSteps:    375001
# Episode 19100/20000 | Avg Reward:  14615.99 | Avg Loss:    0.7987 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    382000 | GradSteps:    377001
# Episode 19200/20000 | Avg Reward:  13767.06 | Avg Loss:    0.7973 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    384000 | GradSteps:    379001
# Episode 19300/20000 | Avg Reward:   1857.92 | Avg Loss:    0.8012 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    386000 | GradSteps:    381001
# Episode 19400/20000 | Avg Reward:   3069.71 | Avg Loss:    0.7773 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    388000 | GradSteps:    383001
# Episode 19500/20000 | Avg Reward:   3742.10 | Avg Loss:    0.8338 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    390000 | GradSteps:    385001
# Episode 19600/20000 | Avg Reward:   2057.20 | Avg Loss:    0.8280 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    392000 | GradSteps:    387001
# Episode 19700/20000 | Avg Reward:   3455.43 | Avg Loss:    0.7605 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    394000 | GradSteps:    389001
# Episode 19800/20000 | Avg Reward:   2365.49 | Avg Loss:    0.7207 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    396000 | GradSteps:    391001
# Episode 19900/20000 | Avg Reward:   2405.69 | Avg Loss:    0.6890 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    398000 | GradSteps:    393001
# Episode 20000/20000 | Avg Reward:   3332.70 | Avg Loss:    0.7984 | Eps: 0.0500 | Buffer:  200000 | EnvSteps:    400000 | GradSteps:    395001
#
# Final Training Statistics:
#   Buffer size: 200,000
#   Final epsilon (step-based): 0.0500
#   Avg reward (last 100 eps): 3332.70
#   Avg loss (last 100 eps): 0.7984

# %% [markdown]
# ## 📊 Comprehensive Comparison: Baseline vs Tabular Q vs DQN
#
# Now let's compare all three approaches on the same evaluation episodes.

# %%
import numpy as np
import pandas as pd
import torch

class TabularWrapper:
    def __init__(self, Q):
        self.Q = Q

    def discretize(self, state_dict):
        # MUST match your training discretization exactly
        # Example (from Claude's code): qty_bin = min(qty_lag1, 8)
        qty_bin = int(min(float(state_dict["qty_lag1"]), 8))
        return qty_bin

    def greedy_action(self, state_dict):
        s_idx = self.discretize(state_dict)
        return int(np.argmax(self.Q[s_idx]))
    
    

def compare_all_methods_fair(
    tabular_agent,          # object with a greedy action method OR pass (Q, discretizer)
    dqn_agent,              # your DQNAgent from the stable setup
    actions,                # ACTION_MULTS array/list
    episode_table,
    demand_model,
    n_eval=1000,
    horizon=20,
    seed=42,
):
    rng = np.random.default_rng(seed)

    # baseline index = multiplier closest to 1.0
    actions = np.asarray(actions, dtype=np.float32)
    baseline_action_idx = int(np.argmin(np.abs(actions - 1.0)))

    results = {
        "baseline": {"returns": [], "actions": []},
        "tabular_q": {"returns": [], "actions": []},
        "dqn": {"returns": [], "actions": []},
    }

    def rollout(policy_name, policy_fn, init_state_dict):
        s = dict(init_state_dict)  # copy
        total_r = 0.0
        acts = []
        for t in range(horizon):
            a_idx = int(policy_fn(s))
            a_mult = actions[a_idx]
            _, r, ns = env_step(demand_model, s, a_mult)
            done = (t == horizon - 1)
            total_r += float(r)
            acts.append(a_idx)
            s = ns
        return total_r, acts

    # --- Define policies ---
    def baseline_policy(state_dict):
        return baseline_action_idx

    # Tabular policy: you must provide how it chooses greedy actions.
    # If your tabular implementation is Q + discretize(state)->s_idx:
    # Replace below with your actual discretizer.
    def tabular_policy(state_dict):
        return tabular_agent.greedy_action(state_dict)  # <- implement this wrapper

    def dqn_policy(state_dict):
        s_vec = state_to_vec(state_dict)
        with torch.no_grad():
            s_t = torch.from_numpy(s_vec).unsqueeze(0).to(dqn_agent.device)
            q = dqn_agent.policy_net(s_t)
            return int(q.argmax(dim=1).item())

    print("Evaluating (fair rollouts): Baseline vs Tabular Q vs DQN")
    print(f"Episodes: {n_eval}, Horizon: {horizon}")
    print("-" * 80)

    for ep in range(n_eval):
        if (ep + 1) % 200 == 0:
            print(f"  Completed {ep + 1}/{n_eval} episodes...")

        idx = int(rng.integers(0, len(episode_table)))
        init_state = episode_table.iloc[idx].to_dict()

        for name, fn in [("baseline", baseline_policy),
                         ("tabular_q", tabular_policy),
                         ("dqn", dqn_policy)]:
            ret, acts = rollout(name, fn, init_state)
            results[name]["returns"].append(ret)
            results[name]["actions"].extend(acts)

    # --- stats ---
    for name in results:
        arr = np.array(results[name]["returns"], dtype=np.float64)
        results[name]["mean"] = float(arr.mean())
        results[name]["std"] = float(arr.std())
        results[name]["median"] = float(np.median(arr))
        results[name]["min"] = float(arr.min())
        results[name]["max"] = float(arr.max())

        counts = pd.Series(results[name]["actions"]).value_counts(normalize=True).sort_index()
        results[name]["action_distribution"] = counts.to_dict()

    # --- win rates ---
    b = np.array(results["baseline"]["returns"])
    t = np.array(results["tabular_q"]["returns"])
    d = np.array(results["dqn"]["returns"])

    results["win_rates"] = {
        "tabular_over_baseline": float(np.mean(t > b)),
        "dqn_over_baseline": float(np.mean(d > b)),
        "dqn_over_tabular": float(np.mean(d > t)),
    }

    return results


# Perform fair comparison
tabular_agent = TabularWrapper(Q)

comparison = compare_all_methods_fair(
    tabular_agent=tabular_agent,
    dqn_agent=agent,
    actions=ACTION_MULTS,
    episode_table=episode_table,
    demand_model=demand_model,
    n_eval=1000,
    horizon=20,
    seed=42
)
comparison["win_rates"], comparison["baseline"]["mean"], comparison["tabular_q"]["mean"], comparison["dqn"]["mean"]
# Out:
# Evaluating (fair rollouts): Baseline vs Tabular Q vs DQN
# Episodes: 1000, Horizon: 20
# --------------------------------------------------------------------------------
#   Completed 200/1000 episodes...
#   Completed 400/1000 episodes...
#   Completed 600/1000 episodes...
#   Completed 800/1000 episodes...
#   Completed 1000/1000 episodes...
# ({'tabular_over_baseline': 0.979,
#   'dqn_over_baseline': 0.854,
#   'dqn_over_tabular': 0.67},
#  1278.564343388718,
#  2882.928115143705,
#  3499.594219187228)

# %% [markdown]
# ### 📈 Results Summary

# %%
import pandas as pd
import numpy as np

print("=" * 90)
print("📈 COMPREHENSIVE COMPARISON: BASELINE vs TABULAR Q vs DQN")
print("=" * 90)

# -----------------------------
# 1) Summary statistics table
# -----------------------------
summary_df = pd.DataFrame({
    "Method": ["Baseline", "Tabular Q-Learning", "DQN"],
    "Mean Reward": [
        comparison["baseline"]["mean"],
        comparison["tabular_q"]["mean"],
        comparison["dqn"]["mean"],
    ],
    "Median Reward": [
        comparison["baseline"]["median"],
        comparison["tabular_q"]["median"],
        comparison["dqn"]["median"],
    ],
    "Std Reward": [
        comparison["baseline"]["std"],
        comparison["tabular_q"]["std"],
        comparison["dqn"]["std"],
    ],
    "Min Reward": [
        comparison["baseline"]["min"],
        comparison["tabular_q"]["min"],
        comparison["dqn"]["min"],
    ],
    "Max Reward": [
        comparison["baseline"]["max"],
        comparison["tabular_q"]["max"],
        comparison["dqn"]["max"],
    ],
})

print("\n📊 Reward Statistics per Episode:")
print(summary_df.to_string(index=False, float_format="%.2f"))

# -----------------------------
# 2) Improvements over baseline
# -----------------------------
baseline_mean = comparison["baseline"]["mean"]
tabular_mean = comparison["tabular_q"]["mean"]
dqn_mean = comparison["dqn"]["mean"]

tabular_impr = (tabular_mean - baseline_mean) / baseline_mean * 100
dqn_impr = (dqn_mean - baseline_mean) / baseline_mean * 100

print("\n💰 Improvement over Baseline:")
print(f"  • Tabular Q-Learning: {tabular_impr:+.2f}%")
print(f"  • DQN:                {dqn_impr:+.2f}%")

# -----------------------------
# 3) Win-rate comparison
# -----------------------------
wr = comparison.get("win_rates", {})

print("\n🏁 Episode-Level Win Rates:")
print(f"  • Tabular Q > Baseline: {wr.get('tabular_over_baseline', np.nan):.3f}")
print(f"  • DQN > Baseline:       {wr.get('dqn_over_baseline', np.nan):.3f}")
print(f"  • DQN > Tabular Q:      {wr.get('dqn_over_tabular', np.nan):.3f}")

# -----------------------------
# 4) Action distribution
# -----------------------------
print("\n🎯 Action Distribution (fraction of actions taken):")
for key, label in [
    ("baseline", "Baseline"),
    ("tabular_q", "Tabular Q-Learning"),
    ("dqn", "DQN"),
]:
    dist = comparison[key].get("action_distribution", {})
    if not dist:
        print(f"  • {label}: (not available)")
        continue

    dist_str = ", ".join([f"{k}: {v:.3f}" for k, v in sorted(dist.items())])
    print(f"  • {label}: {dist_str}")

# -----------------------------
# 5) High-level verdict
# -----------------------------
print("\n🧠 Interpretation:")
if wr.get("dqn_over_tabular", 0) > 0.6:
    print("  • DQN outperforms Tabular Q in a majority of episodes, indicating better generalization.")
elif wr.get("dqn_over_tabular", 0) > 0.5:
    print("  • DQN and Tabular Q have comparable performance with a slight edge to DQN.")
else:
    print("  • Tabular Q matches or outperforms DQN in this setup.")

print("  • Both RL methods significantly outperform the baseline policy.")

print("\n" + "=" * 90)
# Out:
# ==========================================================================================
# 📈 COMPREHENSIVE COMPARISON: BASELINE vs TABULAR Q vs DQN
# ==========================================================================================
#
# 📊 Reward Statistics per Episode:
#             Method  Mean Reward  Median Reward  Std Reward  Min Reward  Max Reward
#           Baseline      1278.56         488.30     6493.45       59.83   178218.01
# Tabular Q-Learning      2882.93         748.96    16615.73      153.77   452457.01
#                DQN      3499.59         847.89    20527.94       37.75   576732.13
#
# 💰 Improvement over Baseline:
#   • Tabular Q-Learning: +125.48%
#   • DQN:                +173.71%
#
# 🏁 Episode-Level Win Rates:
#   • Tabular Q > Baseline: 0.979
#   • DQN > Baseline:       0.854
#   • DQN > Tabular Q:      0.670
#
# 🎯 Action Distribution (fraction of actions taken):
#   • Baseline: 2: 1.000
#   • Tabular Q-Learning: 0: 0.013, 2: 0.464, 4: 0.013, 6: 0.510
#   • DQN: 0: 0.213, 1: 0.004, 2: 0.032, 3: 0.005, 4: 0.030, 5: 0.099, 6: 0.082, 7: 0.534
#
# 🧠 Interpretation:
#   • DQN outperforms Tabular Q in a majority of episodes, indicating better generalization.
#   • Both RL methods significantly outperform the baseline policy.
#
# ==========================================================================================

# %% [markdown]
# ### 📊 Statistical Significance Tests

# %%
import numpy as np
import pandas as pd
from scipy import stats

print("=" * 90)
print("📐 STATISTICAL SIGNIFICANCE TESTS")
print("=" * 90)

# Extract returns
baseline = np.asarray(comparison["baseline"]["returns"], dtype=np.float64)
tabular  = np.asarray(comparison["tabular_q"]["returns"], dtype=np.float64)
dqn      = np.asarray(comparison["dqn"]["returns"], dtype=np.float64)

assert len(baseline) == len(tabular) == len(dqn), "Paired samples must have equal length"

N = len(baseline)
print(f"Paired evaluation episodes: N = {N}")

# --------------------------------------------------
# Helper functions
# --------------------------------------------------
def cohens_d(x, y):
    diff = x - y
    return diff.mean() / diff.std(ddof=1)

def bootstrap_ci(diff, n_boot=10_000, alpha=0.05, seed=0):
    rng = np.random.default_rng(seed)
    means = []
    for _ in range(n_boot):
        sample = rng.choice(diff, size=len(diff), replace=True)
        means.append(sample.mean())
    lo = np.percentile(means, 100 * alpha / 2)
    hi = np.percentile(means, 100 * (1 - alpha / 2))
    return lo, hi

# --------------------------------------------------
# Pairwise comparisons
# --------------------------------------------------
comparisons = [
    ("Tabular Q vs Baseline", tabular, baseline),
    ("DQN vs Baseline", dqn, baseline),
    ("DQN vs Tabular Q", dqn, tabular),
]

rows = []

for name, x, y in comparisons:
    diff = x - y

    # Paired t-test
    t_stat, t_p = stats.ttest_rel(x, y)

    # Wilcoxon signed-rank test (robust to non-normality)
    try:
        w_stat, w_p = stats.wilcoxon(diff)
    except ValueError:
        w_stat, w_p = np.nan, np.nan  # happens if all diffs are zero

    # Bootstrap CI
    ci_lo, ci_hi = bootstrap_ci(diff)

    # Effect size
    d = cohens_d(x, y)

    rows.append({
        "Comparison": name,
        "Mean Diff": diff.mean(),
        "Median Diff": np.median(diff),
        "t-test p-value": t_p,
        "Wilcoxon p-value": w_p,
        "95% CI (low)": ci_lo,
        "95% CI (high)": ci_hi,
        "Cohen's d": d,
    })

results_df = pd.DataFrame(rows)

# Formatting
pd.options.display.float_format = "{:.4g}".format

print("\n📊 Statistical Test Results:")
print(results_df.to_string(index=False))

# --------------------------------------------------
# Interpretation helper
# --------------------------------------------------
print("\n🧠 Interpretation Guide:")
print("• p < 0.05  → statistically significant difference")
print("• Cohen’s d ≈ 0.2 small | 0.5 medium | 0.8+ large effect")
print("• CI excluding 0 → robust improvement")

print("\n" + "=" * 90)
# Out:
# ==========================================================================================
# 📐 STATISTICAL SIGNIFICANCE TESTS
# ==========================================================================================
# Paired evaluation episodes: N = 1000
#
# 📊 Statistical Test Results:
#            Comparison  Mean Diff  Median Diff  t-test p-value  Wilcoxon p-value  95% CI (low)  95% CI (high)  Cohen's d
# Tabular Q vs Baseline       1604        304.5       6.518e-07        1.971e-164          1099           2328     0.1583
#       DQN vs Baseline       2221          417       6.982e-07        5.966e-137          1542           3247     0.1579
#      DQN vs Tabular Q      616.7        163.1       2.989e-06         6.965e-63         431.5          923.5     0.1486
#
# 🧠 Interpretation Guide:
# • p < 0.05  → statistically significant difference
# • Cohen’s d ≈ 0.2 small | 0.5 medium | 0.8+ large effect
# • CI excluding 0 → robust improvement
#
# ==========================================================================================

# %% [markdown]
# ### 📊 Visualization: Revenue Distribution Comparison

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------
# Pull data from YOUR structures
# ----------------------------
actions = np.asarray(ACTION_MULTS, dtype=np.float32)

baseline_revenues = np.asarray(comparison["baseline"]["returns"], dtype=np.float64)
tabular_revenues  = np.asarray(comparison["tabular_q"]["returns"], dtype=np.float64)
dqn_revenues      = np.asarray(comparison["dqn"]["returns"], dtype=np.float64)

# Safety check
n = len(baseline_revenues)
assert len(tabular_revenues) == n and len(dqn_revenues) == n, "Returns must be same length (paired eval)."

# ----------------------------
# Plot
# ----------------------------
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# ================================================================
# 1) Box Plot Comparison
# ================================================================
ax = axes[0, 0]
data_to_plot = [baseline_revenues, tabular_revenues, dqn_revenues]
bp = ax.boxplot(
    data_to_plot,
    labels=["Baseline", "Tabular Q", "DQN"],
    patch_artist=True,
    showmeans=True,
    showfliers=False      # <-- hides outliers
)

# Color the boxes (keep your style)
colors = ["lightcoral", "lightgreen", "lightblue"]
for patch, color in zip(bp["boxes"], colors):
    patch.set_facecolor(color)

ax.set_ylabel("Episode Revenue", fontsize=12)
ax.set_title("Revenue Distribution Comparison (Box Plot)", fontsize=14, fontweight="bold")
ax.grid(axis="y", alpha=0.3)

# Add mean values as text
means = [np.mean(d) for d in data_to_plot]
for i, mean in enumerate(means):
    ax.text(i + 1, mean, f"{mean:.1f}", ha="center", va="bottom", fontweight="bold")

# ================================================================
# 2) Histogram Comparison
# ================================================================
ax = axes[0, 1]

quantiles = np.linspace(0.05, 0.95, 19)

ax.plot(
    quantiles,
    np.quantile(baseline_revenues, quantiles),
    marker="o",
    label="Baseline"
)
ax.plot(
    quantiles,
    np.quantile(tabular_revenues, quantiles),
    marker="o",
    label="Tabular Q"
)
ax.plot(
    quantiles,
    np.quantile(dqn_revenues, quantiles),
    marker="o",
    label="DQN"
)

ax.set_xlabel("Quantile", fontsize=12)
ax.set_ylabel("Episode Revenue", fontsize=12)
ax.set_title("Revenue Quantile Comparison", fontsize=14, fontweight="bold")
ax.legend()
ax.grid(alpha=0.3)



# ================================================================
# 3) Cumulative Revenue Comparison
# ================================================================
ax = axes[1, 0]
episodes = np.arange(1, n + 1)
ax.plot(episodes, np.cumsum(baseline_revenues), label="Baseline", linewidth=2)
ax.plot(episodes, np.cumsum(tabular_revenues),  label="Tabular Q", linewidth=2)
ax.plot(episodes, np.cumsum(dqn_revenues),      label="DQN", linewidth=2)

ax.set_xlabel("Episode", fontsize=12)
ax.set_ylabel("Cumulative Revenue", fontsize=12)
ax.set_title("Cumulative Revenue Over Episodes", fontsize=14, fontweight="bold")
ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# ================================================================
# 4) Action Distribution Comparison
# ================================================================
ax = axes[1, 1]

action_indices = list(range(len(actions)))

baseline_dist = [comparison["baseline"]["action_distribution"].get(i, 0.0) * 100 for i in action_indices]
tabular_dist  = [comparison["tabular_q"]["action_distribution"].get(i, 0.0) * 100 for i in action_indices]
dqn_dist      = [comparison["dqn"]["action_distribution"].get(i, 0.0) * 100 for i in action_indices]

width = 0.25
x = np.arange(len(action_indices))
ax.bar(x - width, baseline_dist, width, label="Baseline", edgecolor="black")
ax.bar(x,         tabular_dist,  width, label="Tabular Q", edgecolor="black")
ax.bar(x + width, dqn_dist,      width, label="DQN", edgecolor="black")

ax.set_xlabel("Action Index", fontsize=12)
ax.set_ylabel("Frequency (%)", fontsize=12)
ax.set_title("Action Distribution Comparison", fontsize=14, fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels([f"{i}\n({actions[i]:.2f})" for i in action_indices], fontsize=9)
ax.legend(loc="upper right")
ax.grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# ----------------------------
# Action mapping printout
# ----------------------------
print("\n📊 Action Mappings:")
print("=" * 80)
for i, mult in enumerate(actions):
    print(f"  Action {i}: Price Multiplier = {mult:.2f}")
# Out:
# /var/folders/56/jqj8nyt12sxbm6rgrnlf06y00000gn/T/ipykernel_90314/3786646037.py:27: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(
# 📊 Action Mappings:
# ================================================================================
#   Action 0: Price Multiplier = 0.90
#   Action 1: Price Multiplier = 0.95
#   Action 2: Price Multiplier = 1.00
#   Action 3: Price Multiplier = 1.05
#   Action 4: Price Multiplier = 1.10
#   Action 5: Price Multiplier = 1.15
#   Action 6: Price Multiplier = 1.20
#   Action 7: Price Multiplier = 1.25

# %% [markdown]
# ### 📊 Performance Ranking and Summary Table
